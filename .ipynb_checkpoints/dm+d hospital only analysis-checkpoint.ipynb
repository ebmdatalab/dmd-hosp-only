# %% [markdown]
# The [NHS dictionary of medicines and devices (dm+d)](https://ebmdatalab.net/what-is-the-dmd-the-nhs-dictionary-of-medicines-and-devices/) has a flags to indicate as to whether a given item should be made available through hospital prescribing [(see tech spec of dm+d)](https://www.nhsbsa.nhs.uk/sites/default/files/2017-02/Data_Model_R2_v3.1_May_2015.pdf). We have [previously investigated some of the hospital flags](https://github.com/ebmdatalab/jupyter-notebooks/blob/3dc1f0d45173ab2dcf3156848df65e7a54be40f2/new_measures/Drafts/Hospital/Primary%20Care%20Prescribing%20of%20%20Hospital%20%20Only%20Medicines.ipynb).
#
# During our [work on zuclopenthixol](https://ebmdatalab.net/zuclopenthixol-acetate-a-new-kind-of-measure-on-openprescribing/) it became apparent that despite being a "hospital only" medicine, it was classified as such and is perhaps being administered inappropriately in primary care.
#
# Building on previous work this notebook sets out to explore primary care prescribing of "hospital only" medicines as defined by the [NHS dm+d](https://ebmdatalab.net/what-is-the-dmd-the-nhs-dictionary-of-medicines-and-devices/)

# %%
#import libraries required for analysis
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps

# %%
## ensuring the format is consistent for pounds and pence
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
sql = '''
WITH presentations_with_some_hospital_only_amps AS (
  SELECT bnf_code
  FROM dmd.amp
  WHERE avail_restrict = 8 and avail_restrict !=9 AND bnf_code IS NOT NULL ##8 relates to hospital only in dmd
  
  UNION DISTINCT 
  
  SELECT vmp.bnf_code
  FROM dmd.vmp
  INNER JOIN dmd.amp
    ON vmp.id = amp.vmp
  WHERE amp.avail_restrict = 8 AND vmp.bnf_code IS NOT NULL
)

SELECT
  pct,
  month,
  presentation AS bnf_name,
  bnf_code,
  SUM(items) AS total_items,
  SUM(actual_cost) AS total_cost
FROM
  hscic.normalised_prescribing_standard AS rx
INNER JOIN
  hscic.ccgs
ON
  rx.pct = ccgs.code
INNER JOIN
  hscic.bnf
ON
  rx.bnf_code = bnf.presentation_code
WHERE
  org_type = 'CCG'
  AND bnf_code IN (SELECT bnf_code FROM presentations_with_some_hospital_only_amps) 
GROUP BY
  pct,
  month,
  bnf_code,
  bnf_name
ORDER BY
  pct,
  month,
  bnf_code'''


df_hospital = bq.cached_read(sql, csv_path='df_hospital.csv', use_cache=True)
df_hospital['month'] = df_hospital['month'].astype('datetime64[ns]')
df_hospital.head()
# Out:
#    pct      month                             bnf_name         bnf_code  \
# 0  00C 2010-08-01  Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA
# 1  00C 2010-08-01              Ondansetron HCl_Tab 8mg  0406000S0AAACAC
# 2  00C 2010-08-01                Clonazepam_Tab 500mcg  0408010F0AAABAB
# 3  00C 2010-08-01                   Clonazepam_Tab 2mg  0408010F0AAACAC
# 4  00C 2010-08-01                Desogestrel_Tab 75mcg  0703021Q0AAAAAA
#
#    total_items  total_cost
# 0            1       10.01
# 1            8      718.58
# 2          107      179.18
# 3            9       26.08
# 4           11       77.50

# %%
df_hospital.nunique()
# Out:
# pct               193
# month             111
# bnf_name          290
# bnf_code          290
# total_items      2129
# total_cost     145033
# dtype: int64

# %%
df_hospital["bnf_name"].unique()
# Out:
# array(['Zuclopenth Acet_Inj 50mg/ml 1ml Amp', 'Ondansetron HCl_Tab 8mg',
#        'Clonazepam_Tab 500mcg', 'Clonazepam_Tab 2mg',
#        'Desogestrel_Tab 75mcg', 'Tadalafil_Tab 20mg',
#        'Midazolam HCl_Inj 2mg/ml 5ml Amp',
#        'Tranexamic Acid_Inj 100mg/ml 5ml Amp',
#        'Oxycodone HCl_Inj 10mg/ml 1ml Amp',
#        'Colistimeth Sod_Inj 1,000,000u Vl',
#        'Gentamicin Sulf_Inj 40mg/ml 2ml Vl',
#        'Oxycodone HCl_Inj 10mg/ml 2ml Amp',
#        'Chlorphenamine Mal_Inj 10mg/ml 1ml Amp',
#        'Oxycodone HCl_Inj 50mg/ml 1ml Amp',
#        'Alfentanil HCl_Inj 5mg/ml 1ml Amp',
#        'Methotrexate_Inj 2.5mg/ml 2ml Vl', 'Ceftriaxone Sod_Inj 250mg Vl',
#        'Levobupivac HCl_Inj 2.5mg/ml 10ml Amp',
#        'Ketamine_Inj 50mg/ml 10ml Vl', 'Amoxicillin Sod_Inj 500mg Vl',
#        'Fluclox Sod_Inj 250mg Vl', 'Viridal Duo_S/Pack Inj 20mcg Cart',
#        'Amikacin_Inj 250mg/ml 2ml Vl',
#        'B.C.G._Blad Instillation 12.5mg Vl',
#        'Ketorolac Trometamol_Inj 30mg/ml 1ml Amp',
#        'Ertapenem Sod_I/V Inf 1g Vl (Dry)',
#        'Rituximab_I/V Inf 10mg/ml 10ml Vl',
#        'Zoledronic Acid_I/V Inf 40mcg/ml 100ml',
#        'Posaconazole_Oral Susp 200mg/5ml',
#        'Levetiracetam_I/V Inf 100mg/ml 5ml Vl',
#        'Viridal Duo_S/Pack Inj 40mcg Cart',
#        'Vancomycin HCl_I/V Inf 500mg Vl',
#        'Daptomycin_I/V Inf 500mg Vl (Dry)', 'Pantoprazole_Inj 40mg Vl',
#        'Ceftriaxone Sod_Inj 2g Vl', 'Ceftriaxone Sod_Inj 1g Vl',
#        'Viridal Duo_S/Pack Inj 10mcg Cart', 'Cefuroxime Sod_Inj 750mg Vl',
#        'Meropenem_Inj 500mg Vl (Dry)',
#        'Alprostadil_S/Pack Inj 20mcg Cart',
#        'Ceftazidime Pentahyd_Inj 1g Vl',
#        'Linezolid_I/V Inf 2mg/ml 300ml Bag',
#        'Etanercept_Inj 50mg/ml 1ml Pf Pen',
#        'Enbrel_Inj 50mg/ml 1ml Pf MyClic Pen', 'Nutricia_preOp Liq',
#        'Metoprolol Tart_Inj 1mg/ml 5ml Amp',
#        'Vancomycin HCl_I/V Inf 1g Vl', 'Phenylbutazone_Tab 100mg',
#        'Gefitinib_Tab 250mg', 'Methotrexate_Inj 25mg/ml 2ml Vl',
#        'Botox_Inj 100u Vl', 'Daptomycin_I/V Inf 350mg Vl (Dry)',
#        'OncoTICE_Blad Instillation 12.5mg Vl',
#        'Etanercept_Inj 25mg Vl + Dil', 'Abatacept_Inj 125mg/1ml Pfs',
#        'Ondemet_Tab 8mg', 'Zoledronic Acid_I/V Inf 40mcg/ml 100mlVl',
#        'Isavuconazole_Cap 100mg',
#        'Piperacillin/Tazobactam_I/VInf 4g/0.5gVl',
#        'Meropenem_Inj 1g Vl (Dry)',
#        'Rapifen Intensive Care_Inj 5mg/1ml Amp',
#        'Alprostadil_S/Pack Inj 10mcg Cart', 'Tofacitinib_Tab 5mg',
#        'Zoledronic Acid_I/V Inf 800mcg/ml 5ml Vl',
#        'Amoxicillin Sod_Inj 1g Vl', 'Etanercept_Inj 25mg/0.5ml Pfs',
#        'Cefotaxime Sod_Inj 1g Vl', 'Co-Amoxiclav_Inj 1g/200mg Vl',
#        'Etanercept_Inj 50mg/1ml Pfs',
#        'Piperacillin/Tazobactam_I/VInf2g/0.25gVl',
#        'Toradol_Inj 30mg/ml 1ml Amp', 'Ceftazidime Pentahyd_Inj 2g Vl',
#        'Etanercept_Inj 10mg Vl + Dil', 'Co-Amoxiclav_Inj 500mg/100mg Vl',
#        'Emtricitabine/Tenofovir_Tab 200mg/245mg',
#        'Fluclox Sod_Inj 500mg Vl', 'Amoxicillin Sod_Inj 250mg Vl',
#        'Chirocaine_Inj 2.5mg/ml 10ml Amp', 'Fluclox Sod_Inj 1g Vl',
#        'Alprostadil_S/Pack Inj 40mcg Cart', 'Enbrel_Inj 50mg/ml Pfs',
#        'Infliximab_Inf 100mg Vl', 'Abacavir/Lamivudine_Tab 600mg/300mg',
#        'Cyclophosphamide_Inj 1g Vl', 'Cefotaxime Sod_Inj 500mg Vl',
#        'Botox_Inj Pdr 50u Vl', 'Aciclovir Sod_Inf I/V 500mg Vl (Dry)',
#        'Phenylbutazone_Tab 200mg', 'Syntocinon_Inj 10u/1ml Amp',
#        'Ibuprofen_Inj 5mg/ml 2ml Amp',
#        'Fondaparinux Sod_Inj 5mg/ml 0.3ml Pfs',
#        'Clopixol Acuphase_Inj 50mg/ml 1ml Amp',
#        'Cefuroxime Sod_Inj 250mg Vl', 'Efavirenz_Tab 600mg',
#        'Misoprostol_Tab 400mcg', 'Tolvaptan_Tab 15mg',
#        'Miglustat_Cap 100mg', 'Fludarabine Phos_Tab 10mg',
#        'Ceftazidime Pentahyd_Inj 500mg Vl',
#        'Atenolol_Inj 500mcg/ml 10ml Amp',
#        'Levobupivac HCl_Inj 5mg/ml 10ml Amp',
#        'Chirocaine_Inj 5mg/ml 10ml Amp',
#        'Clarithromycin_I/V Inf 500mg Vl',
#        'Zinacef_I/M/I/V 750mg Vl (Dry)',
#        'Clindamycin Phos_Inj 150mg/ml 4ml Amp',
#        'Clindamycin Phos_Inj 150mg/ml 2ml Amp',
#        'Tocilizumab_I/V Inf 80mg/4ml Vl', 'Aztreonam_Inj 2g Vl',
#        'Erythromycin_Lactobi I/V Inf 1g Vl', 'Cefuroxime Sod_Inj 1.5g Vl',
#        'Methotrexate_Inj 25mg/ml 20ml Vl',
#        'Betaferon_Inj 300mcg Vl + Dil', 'Ceftazidime Pentahyd_Inj 3g Vl',
#        'Enbrel_Inj 25mg Vl + Dil', 'Tigecycline_I/V Inf 50mg Vl (Dry)',
#        'Enbrel_Inj 25mg/0.5ml Pfs', 'Tocilizumab_Inj 162mg/0.9ml Pfs',
#        'Revatio_Inj 800mcg/ml 12.5ml Vl', 'Orencia_Inj 125mg/1ml Pfs',
#        'Promixin_Inj 1,000,000u Vl (Dry)',
#        'Calc Folinate_Inj 7.5mg/ml 2ml Amp', 'Aztreonam_Inj 1g Vl',
#        'Syntocinon_Inj 5u/1ml Amp', 'Omeprazole_I/V Inf 40mg Vl',
#        'Pegvisomant_Inj 10mg Vl + Dil', 'Capecitabine_Tab 500mg',
#        'Adenosine_I/V Inf 3mg/ml 2ml Vl',
#        'Adenocor_I/V Inf 3mg/ml 2ml Vl', 'Somavert_Inj 20mg Vl + Dil',
#        'Enoximone_Inj 5mg/ml 20ml Amp', 'Perfan_Inj 5mg/ml 20ml Amp',
#        'Botulinum A Toxin_Inj Pdr 100u Vl', 'Metvix_Crm 16%',
#        'Methyl-5-Aminolevulinate_Crm 16%',
#        'Trastuzumab_I/V Inf 150mg Vl (Dry)',
#        'Adren_Inj 1/10,000 10ml Pfs', 'Sutent_Cap 12.5mg',
#        'Sutent_Cap 25mg', 'Caffeine Cit_Inj 20mg/ml 1ml Amp',
#        'Methotrexate_Inj 100mg/ml 10ml Vl',
#        'Fortum_I/M Or I/V Inj 1g Vl (Dry)',
#        'Ciproxin_I/V Inf 2mg/ml 100ml Btl', 'Sunitinib_Cap 12.5mg',
#        'Oxytocin_Inj 10u/ml 1ml Amp', 'Ciproxin_I/V Inf 2mg/ml 200ml Btl',
#        'Aciclovir Sod_Inf I/V 250mg Vl (Dry)', 'Atazanavir_Cap 150mg',
#        'Pegfilgrastim_Inj 10mg/ml 0.6ml Pfs', 'Sunitinib_Cap 50mg',
#        'Flumazenil_Inj 100mcg/ml 5ml Amp',
#        'Ibandronic Acid_I/V Inf 1mg/ml 2ml Vl',
#        'Cubicin_I/V Inf 500mg Vl (Dry)',
#        'Phenytoin_Sod Inj 50mg/ml 5ml Amp', 'Mag Sulf_Inj 10% 10ml Amp',
#        'Fortum_I/M Or I/V Inj 500mg Vl (Dry)', 'Viramune_Tab 100mg M/R',
#        'Arixtra_Inj 1.5mg/0.3ml Pfs',
#        'Ciprofloxacin_I/V Inf 2mg/ml 200ml Btl',
#        'Temocillin Sod_Inj 1g Vl', 'Fortum_I/V Inj/Inf 3g Vl (Dry)',
#        'Esomeprazole_Inj 40mg Vl (Dry)', 'Fampridine_Tab 10mg M/R',
#        'Ciprofloxacin_I/V Inf 2mg/ml 200ml Bag',
#        'Cubicin_I/V Inf 350mg Vl (Dry)',
#        'Alprostadil_I/V Inf 500mcg/ml 1ml Amp', 'Tolvaptan_Tab 30mg',
#        'Jinarc_Tab 15mg', 'Temozolomide_Cap 100mg',
#        'Temozolomide_Cap 20mg', 'Tysabri_I/V Inf 300mg/15ml Vl',
#        'RoActemra_Conc For Inf 80mg/4ml Vl',
#        'Rituximab_I/V Inf 10mg/ml 50ml Vl',
#        'Ranibizumab_Inj 10mg/ml 0.23ml Vl', 'Atazanavir_Cap 300mg',
#        'Ofev_Cap 100mg', 'Aciclovir_I/V Inf 25mg/ml 10ml Vl',
#        'Zoledronic Acid_I/V Inf 50mcg/ml 100mlVl',
#        'Hum Nor Imglob_I/V Inf 5% 10g/200ml Vl',
#        'Hum Nor Imglob_I/V Inf 5% 5g/100ml Vl',
#        'Paracet_I/V Inf 10mg/ml 50ml Btl', 'Nintedanib_Cap 100mg',
#        'Lucentis_Inj 10mg/ml 0.23ml Vl',
#        'Tocilizumab_I/V Inf 200mg/10ml Vl',
#        'Labetalol HCl_Inj 5mg/ml 20ml Amp',
#        'Ciprofloxacin_I/V Inf 2mg/ml 100ml Bag',
#        'Glyceryl Trinit_Inj 5mg/ml 5ml Amp',
#        'Natalizumab_I/V Inf 20mg/ml 15ml Vl',
#        'Zoledronic Acid_I/V Inf 50mcg/ml 100ml',
#        'Noxafil_Oral Susp 40mg/ml', 'Reyataz_Cap 150mg',
#        'Temozolomide_Cap 180mg', 'Ethanol_Inj 100% 2ml Amp',
#        'Sustiva 600_Tab 600mg', 'Negaban_Inj 1g Vl',
#        'Botox_Inj Pdr 200u Vl', 'Botulinum A Toxin_Inj Pdr 50u Vl',
#        'Mepolizumab_Inj 100mg Vl (Dry)',
#        'Gentamicin Sulf_Inj 5mg/ml 1ml Amp', 'Nintedanib_Cap 150mg',
#        'Talmanco_Tab 20mg', 'Nexium I.V._Inj 40mg Vl (Dry)',
#        'Sunitinib_Cap 25mg', 'Netupitant/Palonosteron_Cap 300mg/500mcg',
#        'Inflectra_Inf 100mg Vl', 'Atracurium Besil_Inj 10mg/ml 2.5ml Amp',
#        'Axitinib_Tab 5mg', 'RoActemra_Inj 162mg/0.9ml Pfs',
#        'Erelzi_Inj 50mg/ml 1ml Pf Pen',
#        'Sildenafil_Inj 800mcg/ml 12.5ml Vl', 'Fortum_I/V Inj 2g Vl (Dry)',
#        'Carboplatin_I/V Inf 10mg/ml 15ml Vl',
#        'Ropivacaine HCl_Inj 7.5mg/ml 10ml Amp',
#        'Ciprofloxacin_I/V Inf 2mg/ml 100ml Btl',
#        'Azactam_Inj 1g Vl (Dry)', 'Gelatin_I/V Inf 4% 500ml',
#        'Dalacin C Phos_Inj 150mg/ml 4ml Amp',
#        'Pegvisomant_Inj 15mg Vl + Dil',
#        'Voriconazole_I/V Inf 200mg Vl (Dry)',
#        'Lumacaftor/Ivacaftor_Tab 200mg/125mg',
#        'Interf B 1b_Inj 300mcg Vl + Dil', 'Prostin_E2 Gel 1mg/2.5ml Pfs',
#        'Remicade_Inf 100mg Vl', 'Pegvisomant_Inj 20mg Vl + Dil',
#        'Levofloxacin_I/V Inf 5mg/ml 100ml Vl', 'Dabrafenib_Cap 75mg',
#        'Moxifloxacin_I/V Inf 1.6mg/ml 250ml Btl',
#        'Pamidronate Disod_I/V Inf 9mg/ml 10ml Vl', 'Temodal_Cap 5mg',
#        'Tygacil_I/V Inf 50mg Vl (Dry)', 'Ofev_Cap 150mg',
#        'Ciprofloxacin_I/V Inf 2mg/ml 50ml Btl',
#        'Calc Folinate_Inj 10mg/ml 10ml Vl',
#        'Calc Folinate_Inj 10mg/ml 30ml Vl',
#        'Calc Folinate_Inj 10mg/ml 5ml Vl', 'Remsima_Inf 100mg Vl',
#        'Ibandronic Acid_I/V Inf 1mg/ml 6ml Vl',
#        'Mycophenolate Mofetil_Inj 500mg Vl', 'Nevirapine_Tab 100mg M/R',
#        'Sustiva_Cap 200mg', 'Somavert_Inj 10mg Vl + Dil',
#        'Fluorouracil_Inj 50mg/ml 10ml Vl',
#        'Octagam_I/V Inf 10% 10g/100ml Btl', 'Atazanavir_Cap 200mg',
#        'Eptifibatide_I/V Inf 750mcg/ml 100ml Vl', 'Efavirenz_Cap 50mg',
#        'Fampyra_Tab 10mg M/R', 'Cisatracurium_Inj 2mg/ml 10ml Amp',
#        'NeuroBloc_Inj 5,000u/ml 1ml Vl',
#        'Anidulafungin_I/V Inf Pdr 100mg Vl',
#        'Pancuronium Brom_Inj 2mg/ml 2ml Amp',
#        'Botulinum A Toxin_Inj Pdr 200u Vl', 'Efavirenz_Cap 200mg',
#        'Ciproxin_I/V Inf 2mg/ml 50ml Btl', 'Sutent_Cap 50mg',
#        'Pamidronate Disod_I/V Inf 3mg/ml 5ml Vl',
#        'Abatacept_I/V Inf 250mg Vl (Dry)',
#        'Pegvisomant_Inj 30mg Vl + Dil', 'Mitomycin_Inj 20mg Vl',
#        'Hum Nor Imglob_I/V Inf 5g/50ml Vl',
#        'Hum Nor Imglob_I/V Inf 10g/100ml Vl',
#        'Hum Nor Imglob_I/V Inf 20g/200ml Vl',
#        'Chirocaine_Inj 7.5mg/ml 10ml Amp',
#        'Levobupivac HCl_Inj 7.5mg/ml 10ml Amp',
#        'Levofloxacin_I/V Inf 5mg/ml 100ml Bag',
#        'Mitoxantrone_Inj 2mg/ml 10ml Vl',
#        'Etanercept_Inj 50mg/ml 0.5ml Pf Pen',
#        'Oxytocin_Inj 5u/ml 1ml Amp', 'Temozolomide_Cap 5mg',
#        'Temozolomide_Cap 140mg', 'Volplex_I/V Inf 4% 500ml',
#        'Myozyme_I/V Inf 50mg Vl (Dry)', 'Fluclox Sod_Inj 2g Vl',
#        'Fludara_Tab 10mg', 'Bupivac/Fentanyl_Inf 250mg/500mcg/250ml',
#        'Aciclovir_I/V Inf 25mg/ml 20ml Vl',
#        'Gelaspan_Ecobag I/V Inf 4% 500ml',
#        'Amiodarone HCl_Inj 50mg/ml 3ml Amp',
#        'RoActemra_Conc For Inf 200mg/10ml Vl',
#        'Docetaxel_I/V Inf 20mg/1ml Vl',
#        'Fluconazole_I/V Inf 2mg/ml 100ml Bag',
#        'Cyclophosphamide_Inj 500mg Vl', 'Palbociclib_Cap 125mg',
#        'Ustekinumab_I/V Inf 5mg/ml 26ml Vl',
#        'Pamidronate Disod_I/V Inf 3mg/ml 10ml Vl', 'Axitinib_Tab 7mg',
#        'Cytarabine_Inj 100mg/ml 10ml Vl', 'Ultiva_Inj 1mg Vl (Dry)',
#        'Epanutin_Inj 50mg/ml 5ml Amp', 'Akynzeo_Cap 300mg/0.5mg',
#        'Botulinum B Toxin_Inj 5,000u/ml 0.5ml Vl'], dtype=object)

# %% [markdown]
# There are 290 unique names but at a glance they seem to be overwhelmingly what we would expect to be "hospital only" medicines. However many are for iv antibiotics and some other medicines where some areas have pioneered the use of specialist communiyt teams to adminster medicines in a patients own home to avoid a hospital admission. These may no longer be truly "hospital only".

# %%
##groupby bnf name  to see "biggest offenders" in terms of items
df_product = df_hospital.groupby(['bnf_code', 'bnf_name']).sum().sort_values(by = 'total_items', ascending = False).reset_index()
df_product.head(25)
# Out:
#            bnf_code                                  bnf_name  total_items  \
# 0   0703021Q0AAAAAA                     Desogestrel_Tab 75mcg      8712329
# 1   0408010F0AAABAB                     Clonazepam_Tab 500mcg      6645674
# 2   0704050R0AAABAB                        Tadalafil_Tab 20mg      3347874
# 3   0408010F0AAACAC                        Clonazepam_Tab 2mg       976242
# 4   0406000S0AAACAC                   Ondansetron HCl_Tab 8mg       203372
# 5   0407020ADAAALAL         Oxycodone HCl_Inj 10mg/ml 1ml Amp       176474
# 6   0501070I0AAABAB         Colistimeth Sod_Inj 1,000,000u Vl        44048
# 7   1501041T0AAABAB          Midazolam HCl_Inj 2mg/ml 5ml Amp        36619
# 8   0407020ADAAAMAM         Oxycodone HCl_Inj 10mg/ml 2ml Amp        32949
# 9   0407020ADAAANAN         Oxycodone HCl_Inj 50mg/ml 1ml Amp        29043
# 10  0304010G0AAAAAA    Chlorphenamine Mal_Inj 10mg/ml 1ml Amp        11583
# 11  1501043A0AAADAD         Alfentanil HCl_Inj 5mg/ml 1ml Amp         9508
# 12  0501021G0AAACAC                 Ceftriaxone Sod_Inj 1g Vl         8343
# 13  0501021G0AAADAD                 Ceftriaxone Sod_Inj 2g Vl         7982
# 14  0501040H0AAAMAM        Gentamicin Sulf_Inj 40mg/ml 2ml Vl         6892
# 15  0211000P0AAAAAA      Tranexamic Acid_Inj 100mg/ml 5ml Amp         4718
# 16  0501022B0AAAAAA         Ertapenem Sod_I/V Inf 1g Vl (Dry)         3288
# 17  0704050B0BCAIBN         Viridal Duo_S/Pack Inj 40mcg Cart         2832
# 18  1501010F0AAABAB              Ketamine_Inj 50mg/ml 10ml Vl         2667
# 19  0704050B0BCAGBL         Viridal Duo_S/Pack Inj 20mcg Cart         2425
# 20  0501022A0AAAAAA              Meropenem_Inj 500mg Vl (Dry)         2401
# 21  1501042E0AAAAAA  Ketorolac Trometamol_Inj 30mg/ml 1ml Amp         2355
# 22  0501013C0AAADAD              Amoxicillin Sod_Inj 500mg Vl         2221
# 23  0801030P0AAANAN           Methotrexate_Inj 25mg/ml 2ml Vl         2160
# 24  0704050B0BCAHBM         Viridal Duo_S/Pack Inj 10mcg Cart         1931
#
#      total_cost
# 0   40588488.84
# 1   42378271.08
# 2  103873793.95
# 3    5511789.02
# 4    9653055.72
# 5    3159319.21
# 6    4536933.97
# 7     252428.35
# 8    1775587.44
# 9    6553966.03
# 10    521078.06
# 11    477239.82
# 12    441301.89
# 13   1080849.16
# 14    485906.09
# 15    130761.11
# 16    772565.28
# 17    171457.62
# 18    169989.65
# 19    109954.02
# 20    615342.66
# 21     38800.67
# 22     43217.02
# 23     42728.36
# 24     64961.67

# %% [markdown]
# Some comments
# - desogesterel is definitely not a hospital only medicine. It is a commonly used contraceptive. The [brand Moonia](https://openprescribing.net/dmd/amp/36546611000001102/) has been classed as hospital only and affects the figures.
# - Clonazepam would not be considered a "hospital only" medicine. Reviewing dm+d it appears that a [product by Star Pharmaceuticals](https://openprescribing.net/dmd/advanced-search/amp/?search=%5B%22and%22%2C%5B%5B%22nm%22%2C%22contains%22%2C%22clonazep%22%5D%2C%5B%22avail_restrict%22%2C%22equal%22%2C%228%22%5D%5D%5D) has been designated "hospital only" while all other clonazepam products are not. I can't find the SPC for Star Pharmaceutical to see if there is some licnese difference but it is likely that this is a misclassification.
# - Colistimeth Sod: This is used iv but also inhaled in treatment of lung infections particularly Cystic Fibrosis. [NHS England states](https://www.england.nhs.uk/wp-content/uploads/2019/04/nhs-england-drugs-list-v14.1.pdf) that when used for treatment of infections related to Cystic Fibrosis it is suiatable for shared care i.e. a GP could prescribe on FP10.
# Reviewing the [	Colistimethate 1million unit powder for solution for injection vials](https://openprescribing.net/dmd/vmp/324311004/)  AMPs more closely we find differences in the designations dependent on product.
#
# | AMP  | Hospital Only   |
# |------|-----------------|
# | [Colomycin](https://openprescribing.net/dmd/amp/3108611000001108/)*| No|
# |[Promixin](https://openprescribing.net/dmd/amp/4658711000001106/) | Yes|
# |[Kent Pharm](https://openprescribing.net/dmd/amp/17652211000001105/) | Yes|
# |[AAH](https://openprescribing.net/dmd/amp/18758011000001102/)** | No |
#
#         *The IV produc also has a license to be used by inhalation
#         ** Most likely a make believe wholesaler product
#
# - Antibiotics: The list is mainly antibiotics or palliatve care medicines. We do see these medicines in the community nowadays as the NHS seeks to keep people out of hospital. Potentially it is inapprorpriate to label these medicines "hospital only".
#
# **Conclusion**
# 1 - We must investigate which products that are "mixed" i.e. should be excluded as it looks like an error in classification e.g. clonazepam and which should be retained for analysis as there is possibly a reason why AMPs differ e.g. colistin

# %%
sql = '''WITH s AS (
  SELECT bnf_code, nm, avail_restrict
  FROM dmd.amp
  WHERE avail_restrict != 9 AND bnf_code IS NOT NULL

  UNION DISTINCT

  SELECT vmp.bnf_code, vmp.nm, amp.avail_restrict
  FROM dmd.vmp
  INNER JOIN dmd.amp
    ON vmp.id = amp.vmp
  WHERE amp.avail_restrict != 9 AND vmp.bnf_code IS NOT NULL

  ORDER BY bnf_code
)

SELECT bnf_code, nm,  hospital_only, COUNT(*) AS c
FROM (
  SELECT
    bnf_code,
    nm,
    CASE COUNT(CASE WHEN avail_restrict = 8 THEN 1 ELSE NULL END)
    WHEN 0 THEN "Not hospital only"
    WHEN COUNT(*) THEN "Hospital only"
    ELSE "Mixture"
    END AS hospital_only
  FROM
    s
  WHERE
    avail_restrict != 9 AND
    bnf_code IS NOT NULL    
  GROUP BY
    bnf_code, nm
  ORDER BY
    bnf_code
) WHERE hospital_only = "Mixture"
GROUP BY hospital_only, bnf_code, nm
ORDER BY bnf_code'''

df_mixed = bq.cached_read(sql, csv_path='df_mixed.csv', use_cache=True)
pd.set_option('display.max_rows', None) 
df_mixed
# Out:
#             bnf_code                                                 nm  \
# 0    0103050R0AAACAC  Pantoprazole 40mg powder for solution for inje...
# 1    0203020C0AAABAB    Adenosine 30mg/10ml solution for infusion vials
# 2    0203020D0AAADAD  Amiodarone 150mg/3ml concentrate for solution ...
# 3    0203020D0AAADAD  Amiodarone 150mg/3ml solution for injection am...
# 4    0204000I0AAAAAA  Labetalol 100mg/20ml solution for injection am...
# 5    0206010I0AAACAC  Isosorbide dinitrate 10mg/10ml solution for in...
# 6    0207010F0AAAAAA  Dopamine 200mg/5ml solution for infusion ampoules
# 7    0207020R0AAAFAF  Noradrenaline (base) 4mg/4ml solution for infu...
# 8    0207030A0AAABAB  Adrenaline (base) 1mg/10ml (1 in 10,000) dilut...
# 9    0211000H0AAAEAE  Aprotinin 500,000 Kallikrein inactivator units...
# 10   0211000J0AAAEAE  High Purity Factor IX 500unit powder and solve...
# 11   0211000J0AAAFAF  High Purity Factor IX 1,000unit powder and sol...
# 12   0211000P0AAAAAA  Tranexamic acid 500mg/5ml solution for injecti...
# 13   0304010G0AAAAAA  Chlorphenamine 10mg/1ml solution for injection...
# 14   0406000S0AAACAC                            Ondansetron 8mg tablets
# 15   0407020ADAAALAL  Oxycodone 10mg/1ml solution for injection ampo...
# 16   0407020ADAAAMAM  Oxycodone 20mg/2ml solution for injection ampo...
# 17   0407020ADAAANAN  Oxycodone 50mg/1ml solution for injection ampo...
# 18   0408010A0AAAJAJ  Levetiracetam 500mg/5ml concentrate for soluti...
# 19   0408010A0AAAJAJ  Levetiracetam 500mg/5ml solution for infusion ...
# 20   0408010F0AAABAB                    Clonazepam 500microgram tablets
# 21   0408010F0AAACAC                             Clonazepam 2mg tablets
# 22   0408020T0AAAAAA  Phenytoin sodium 250mg/5ml solution for inject...
# 23   0409030B0AAADAD  Botulinum toxin type A 50unit powder for solut...
# 24   0409030B0AAAEAE  Botulinum toxin type A 100unit powder for solu...
# 25   0501012G0AAACAC  Flucloxacillin 250mg powder for solution for i...
# 26   0501012G0AAADAD  Flucloxacillin 500mg powder for solution for i...
# 27   0501012G0AAAEAE  Flucloxacillin 1g powder for solution for inje...
# 28   0501013C0AAACAC  Amoxicillin 250mg powder for solution for inje...
# 29   0501013C0AAADAD  Amoxicillin 500mg powder for solution for inje...
# 30   0501013C0AAAEAE  Amoxicillin 1g powder for solution for injecti...
# 31   0501013K0AAAEAE  Co-amoxiclav 500mg/100mg powder for solution f...
# 32   0501013K0AAAFAF  Co-amoxiclav 1000mg/200mg powder for solution ...
# 33   0501014S0AAAAAA  Piperacillin 2g / Tazobactam 250mg powder for ...
# 34   0501014S0AAABAB  Piperacillin 4g / Tazobactam 500mg powder for ...
# 35   0501021D0AAAAAA  Cefotaxime 500mg powder for solution for injec...
# 36   0501021D0AAABAB  Cefotaxime 1g powder for solution for injectio...
# 160  0801050V0AAABAB  Paclitaxel 100mg/16.7ml solution for infusion ...
# 161  0801050V0AAACAC  Paclitaxel 150mg/25ml concentrate for solution...
# 162  0801050V0AAACAC  Paclitaxel 150mg/25ml solution for infusion vials
# 163  0801050V0AAADAD  Paclitaxel 300mg/50ml concentrate for solution...
# 164  0801050V0AAADAD  Paclitaxel 300mg/50ml solution for infusion vials
# 165  0801050Y0AAAAAA                        Temozolomide 100mg capsules
# 166  0801050Y0AAABAB                        Temozolomide 250mg capsules
# 167  0801050Y0AAACAC                          Temozolomide 5mg capsules
# 168  0801050Y0AAADAD                         Temozolomide 20mg capsules
# 169  0801050Y0AAAEAE                        Temozolomide 140mg capsules
# 170  0801050Y0AAAFAF                        Temozolomide 180mg capsules
# 171  0802010M0AAAHAH  Mycophenolate mofetil 500mg powder for solutio...
# 172  0802030F0AAAAAA   Rituximab 500mg/50ml solution for infusion vials
# 173  0802030F0AAABAB   Rituximab 100mg/10ml solution for infusion vials
# 174  0802040M0AAADAD  Interferon beta-1b 300microgram powder and sol...
# 175  0901060P0AAAAAA  Pegfilgrastim 6mg/0.6ml solution for injection...
# 176  0902022I0AAAAAA                     Gelatin 4% infusion 500ml bags
# 177  0905013N0AAABAB  Magnesium sulfate 10% (magnesium 0.4mmol/ml) s...
# 178  1001010Q0AAABAB                       Phenylbutazone 100mg tablets
# 179  1001030D0AAACAC  Etanercept 50mg/1ml solution for injection pre...
# 180  1001030D0AAADAD  Etanercept 25mg/0.5ml solution for injection p...
# 181  1001030D0AAAEAE  Etanercept 50mg/1ml solution for injection pre...
# 182  1405010A0AAACAC  Normal immunoglobulin human 10g/200ml solution...
# 183  1405010A0AAANAN  Normal immunoglobulin human 5g/100ml solution ...
# 184  1405010A0AABPBP  Normal immunoglobulin human 5g/50ml solution f...
# 185  1405010A0AABQBQ  Normal immunoglobulin human 10g/100ml solution...
# 186  1405010A0AABRBR  Normal immunoglobulin human 20g/200ml solution...
# 187  1405010A0AABXBX  Normal immunoglobulin human 2g/20ml solution f...
# 188  1501010F0AAABAB   Ketamine 500mg/10ml solution for injection vials
# 189  1501041T0AAABAB  Midazolam 10mg/5ml solution for injection ampo...
# 190  1501043A0AAADAD  Alfentanil 5mg/1ml solution for injection ampo...
# 191  1501050F0AAAAAA  Atracurium besilate 25mg/2.5ml solution for in...
# 192  1501050F0AAABAB  Atracurium besilate 50mg/5ml solution for inje...
# 193  1501050F0AAADAD  Atracurium besilate 250mg/25ml solution for in...
# 194  1501050W0AAACAC  Cisatracurium besilate 20mg/10ml solution for ...
# 195  1501050W0AAADAD  Cisatracurium besilate 150mg/30ml solution for...
# 196  1501050X0AAABAB  Rocuronium bromide 100mg/10ml solution for inj...
# 197  1501050X0AAACAC  Rocuronium bromide 50mg/5ml solution for injec...
# 198  1501070F0AAAAAA  Flumazenil 500micrograms/5ml solution for inje...
# 199  1502010R0AAAAAA  Ropivacaine 20mg/10ml solution for injection a...
# 200  1502010R0AAABAB  Ropivacaine 75mg/10ml solution for injection a...
# 201  1502010R0AAADAD              Ropivacaine 400mg/200ml infusion bags
# 135       Mixture  1
# 136       Mixture  1
# 137       Mixture  1
# 138       Mixture  1
# 139       Mixture  1
# 140       Mixture  1
# 141       Mixture  1
# 142       Mixture  1
# 143       Mixture  1
# 144       Mixture  1
# 145       Mixture  1
# 146       Mixture  1
# 147       Mixture  1
# 148       Mixture  1
# 149       Mixture  1
# 150       Mixture  1
# 151       Mixture  1
# 152       Mixture  1
# 153       Mixture  1
# 154       Mixture  1
# 155       Mixture  1
# 156       Mixture  1
# 157       Mixture  1
# 158       Mixture  1
# 159       Mixture  1
# 160       Mixture  1
# 161       Mixture  1
# 162       Mixture  1
# 163       Mixture  1
# 164       Mixture  1
# 165       Mixture  1
# 166       Mixture  1
# 167       Mixture  1
# 168       Mixture  1
# 169       Mixture  1
# 170       Mixture  1
# 171       Mixture  1
# 172       Mixture  1
# 173       Mixture  1
# 174       Mixture  1
# 175       Mixture  1
# 176       Mixture  1
# 177       Mixture  1
# 178       Mixture  1
# 179       Mixture  1
# 180       Mixture  1
# 181       Mixture  1
# 182       Mixture  1
# 183       Mixture  1
# 184       Mixture  1
# 185       Mixture  1
# 186       Mixture  1
# 187       Mixture  1
# 188       Mixture  1
# 189       Mixture  1
# 190       Mixture  1
# 191       Mixture  1
# 192       Mixture  1
# 193       Mixture  1
# 194       Mixture  1
# 195       Mixture  1
# 196       Mixture  1
# 197       Mixture  1
# 198       Mixture  1
# 199       Mixture  1
# 200       Mixture  1
# 201       Mixture  1
# 202       Mixture  1

# %% [markdown]
# On reviewing this list for the vast majority of products it makes no sense why one AMP would be "hospital only" and why another is not. These are probably inconsistencies as companies and the not NHS controls what is "hospital only". We should send this to BSA to support their review processes.

# %% [markdown]
# To continue our analyis let us manually filter the preparations that are obviously not (based on clinical experience) "hospital only" from df_product

# %%
#'this is the list'
names = ["Clonazepam_Tab 500mcg", "Clonazepam_Tab 2mg", "Desogestrel_Tab 75mcg", "Tadalafil_Tab 20mg", "Clonazepam_Tab 2mg", "Ondansetron HCl_Tab 8mg"]

# %%
## let us drop clonazepam before we proceed
#df_filtered = df_hospital[df_hospital["bnf_name"].str.contains(names) == False].sort_values("bnf_name")
df_filtered = df_hospital[~df_hospital['bnf_name'].isin(names)]
df_filtered.head()
# Out:
#     pct      month                              bnf_name         bnf_code  \
# 0   00C 2010-08-01   Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA
# 6   00C 2010-08-01      Midazolam HCl_Inj 2mg/ml 5ml Amp  1501041T0AAABAB
# 7   00C 2010-09-01  Tranexamic Acid_Inj 100mg/ml 5ml Amp  0211000P0AAAAAA
# 9   00C 2010-09-01     Oxycodone HCl_Inj 10mg/ml 1ml Amp  0407020ADAAALAL
# 14  00C 2010-09-01      Midazolam HCl_Inj 2mg/ml 5ml Amp  1501041T0AAABAB
#
#     total_items  total_cost
# 0             1       10.01
# 6             3       19.54
# 7             2       42.77
# 9             1       14.76
# 14            2       11.73

# %%
##here we plot trend over time.
df_filtered.groupby("month")['total_cost'].sum().plot(kind='line', title="Total cost of dm+d hospital only medicines prescribing")
plt.ylim(0, )
# Out:
# (0, 534921.870696501)

# %%
##here we plot trend over time.
df_filtered.groupby("month")['total_items'].sum().plot(kind='line', title="Total items dm+d hospital only medicines prescribing")
plt.ylim(0, )
# Out:
# (0, 5368.2)

# %% [markdown]
# In 2016 there was a substanitial drop and now the costs are approximatelt £270k per month while items have been steadily increasing.

# %% [markdown]
# ## Infrequently prescribed
# Frequently prescribed items are probably not truly "hospital only" medicines anymore. We are interested in infrequently prescribed medicines that are "hospital only" and possibly a mistake. We highlighted some of this in our [zuclopenthixol blog](https://ebmdatalab.net/zuclopenthixol-acetate-a-new-kind-of-measure-on-openprescribing/) and Callum's [high dose dexamethaone blog](https://ebmdatalab.net/opendemocratisation-of-data-guest-blog-high-dose-dexamethasone/) where things aren't flagged as "hospital only" but probably are. Let us set the threshold of items in a year as similar (but arbitrary) to zuclopenthixol at 75

# %%
infreq = df_filtered.loc[(df_filtered['month'] >= '2018-11-01') & (df_filtered['month'] <= '2019-10-01')] ##restrict to last 12 months

# %%
infreq2 = infreq.groupby(["bnf_name", "bnf_code"]).sum().sort_values('total_items', ascending=True).reset_index() ##group and sort by items
infreq2.to_csv("infreq_hosponly.csv") ## export to csv for anyone for further investigation/emailing to interested folks

# %%
## Now lets restict to 75 as per rationale above
inf_hosp_only = infreq2.loc[(infreq2['total_items'] < 75)]
pd.set_option('display.max_rows', None) 
inf_hosp_only
# Out:
#                                     bnf_name         bnf_code  total_items  \
# 0               Prostin_E2 Gel 1mg/2.5ml Pfs  0701010I0BBAFAF            1
# 1       Levofloxacin_I/V Inf 5mg/ml 100ml Vl  0501120X0AAACAC            1
# 2                 Cefuroxime Sod_Inj 1.5g Vl  0501021J0AAACAC            1
# 3                         Sunitinib_Cap 25mg  0801050AMAAABAB            1
# 4                         Sunitinib_Cap 50mg  0801050AMAAACAC            1
# 5                          Talmanco_Tab 20mg  0704050R0BDAAAB            1
# 6                        Dabrafenib_Cap 75mg  0802040AIAAABAB            1
# 7          Tigecycline_I/V Inf 50mg Vl (Dry)  0501030Y0AAAAAA            1
# 8            Tocilizumab_Inj 162mg/0.9ml Pfs  1001030W0AAADAD            1
# 9          Daptomycin_I/V Inf 350mg Vl (Dry)  0501070Y0AAAAAA            1
# 10                     Palbociclib_Cap 125mg  0801050CBAAACAC            1
# 11                  Enbrel_Inj 25mg Vl + Dil  1001030D0BBAAAA            1
# 12            Mepolizumab_Inj 100mg Vl (Dry)  0304020Y0AAAAAA            1
# 13                   Infliximab_Inf 100mg Vl  1001030T0AAAAAA            1
# 14         Labetalol HCl_Inj 5mg/ml 20ml Amp  0204000I0AAAAAA            1
# 15        Mycophenolate Mofetil_Inj 500mg Vl  0802010M0AAAHAH            1
# 16               Abatacept_Inj 125mg/1ml Pfs  1001030V0AAABAB            1
# 17         Aciclovir_I/V Inf 25mg/ml 10ml Vl  0503021C0AAAIAI            1
# 18                    Misoprostol_Tab 400mcg  0701010X0AAAAAA            1
# 19  Zoledronic Acid_I/V Inf 40mcg/ml 100mlVl  0606020V0AAAEAE            1
# 95      Enbrel_Inj 50mg/ml 1ml Pf MyClic Pen  1001030D0BBAFAE           66
# 96  Piperacillin/Tazobactam_I/VInf 4g/0.5gVl  0501014S0AAABAB           67
#
#     total_cost
# 0        12.34
# 1        69.63
# 2       394.33
# 3      1458.50
# 4       104.19
# 5       387.55
# 6        46.57
# 7       810.00
# 8       212.00
# 9        57.58
# 10     2740.73
# 11      331.94
# 12      780.65
# 13      386.00
# 14     2172.41
# 15        8.17
# 16     1124.13
# 17       27.84
# 18      416.33
# 19      247.88
# 20       13.57
# 21       64.08
# 22      130.02
# 23     1996.62
# 24     1993.36
# 25     1587.15
# 26       23.44
# 27      110.50
# 28      681.51
# 29     1473.63
# 30       87.53
# 31       40.89
# 32       66.49
# 33     3718.49
# 34       19.00
# 35       13.06
# 36       68.52
# 37      615.36
# 38      581.05
# 39      250.64
# 40    23482.33
# 41     1659.12
# 42      107.65
# 43      119.17
# 44     1008.76
# 45     1933.04
# 46     2054.67
# 47        9.18
# 48     1682.85
# 49     2590.73
# 50      568.55
# 51      114.09
# 52    15333.28
# 53      136.39
# 54     1940.41
# 55      637.30
# 56      272.15
# 57      265.91
# 58     1595.67
# 59     3636.35
# 60     1384.52
# 61     4105.31
# 62     2622.79
# 63     4087.77
# 64     9701.03
# 65    20899.42
# 66      313.62
# 67     2482.64
# 68     1190.06
# 69     2478.07
# 70      611.34
# 71     1630.26
# 72     3413.71
# 73     2710.83
# 74     1026.84
# 75      266.16
# 76     4687.14
# 77     2766.66
# 78      286.28
# 79     1260.74
# 80     4074.70
# 81      889.72
# 82       67.66
# 83     4845.72
# 84    25187.71
# 85     7398.47
# 86      470.69
# 87     1272.67
# 88      685.97
# 89     7872.46
# 90    13696.83
# 91     6784.43
# 92     2950.77
# 93    15568.93
# 94     5708.64
# 95   127340.46
# 96    15634.70

# %% [markdown]
# In the last year there are quite a few medicines that I have never heard of, that seem more suitable for secondary care but are being prescribed by practices. This is possible for rare unique cases although we must be mindful for errors abd this requires further investigation. For example is there any circumstance where a GP would prescribe _Rapifen Intensive Care_ which is a powerful opioid? Enbrel cost over £100k in primary care - this should be supplied through secondary care to avail of discounts?

# %% [markdown]
# ## Prototype Measure and Maps

# %%
##get list size info for a measure per 1000 patients
sql2 = """
SELECT month, 
pct_id AS pct,
AVG(total_list_size) AS list_size
FROM ebmdatalab.hscic.practice_statistics
group by 
month, pct
order by
month, pct,
list_size
"""
df_list = bq.cached_read(sql2, csv_path='listsize.csv')
df_list['month'] = df_list['month'].astype('datetime64[ns]')
df_list.head(5)
# Out:
#        month  pct  list_size
# 0 2014-11-01  NaN       0.00
# 1 2014-11-01  00C    7616.00
# 2 2014-11-01  00D    5662.51
# 3 2014-11-01  00F    6102.18
# 4 2014-11-01  00G    8058.75

# %%
ccg_total_hosp = df_filtered.groupby(["month", "pct"])["total_items","total_cost"].sum().reset_index()
ccg_total_hosp.head()
# Out:
#        month  pct  total_items  total_cost
# 0 2010-08-01  00C            4       29.55
# 1 2010-08-01  00D           12      874.23
# 2 2010-08-01  00J           23     1227.17
# 3 2010-08-01  00K            2      278.16
# 4 2010-08-01  00L           16     1513.16

# %%
x = df_filtered.groupby(["month", "pct", "bnf_name", "bnf_code"])["total_items","total_cost"].sum().reset_index()
x.head()
# Out:
#        month  pct                             bnf_name         bnf_code  \
# 0 2010-08-01  00C     Midazolam HCl_Inj 2mg/ml 5ml Amp  1501041T0AAABAB
# 1 2010-08-01  00C  Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA
# 2 2010-08-01  00D    Colistimeth Sod_Inj 1,000,000u Vl  0501070I0AAABAB
# 3 2010-08-01  00D         Ketamine_Inj 50mg/ml 10ml Vl  1501010F0AAABAB
# 4 2010-08-01  00D     Midazolam HCl_Inj 2mg/ml 5ml Amp  1501041T0AAABAB
#
#    total_items  total_cost
# 0            3       19.54
# 1            1       10.01
# 2            6      516.22
# 3            1      290.55
# 4            2        8.46

# %%
#merge dataframes and cost / 10000

hosp_df_1000 = pd.merge(ccg_total_hosp, df_list, on=['month', 'pct'])
hosp_df_1000['cost_per_1000'] = 1000* (hosp_df_1000['total_cost']/hosp_df_1000['list_size'])
hosp_df_1000['items_per_1000'] = 1000* (hosp_df_1000['total_items']/hosp_df_1000['list_size'])
hosp_df_1000.head(5)
# Out:
#        month  pct  total_items  total_cost  list_size  cost_per_1000  \
# 0 2014-11-01  00C            8     3011.56    7616.00         395.43
# 1 2014-11-01  00D           29     7899.22    5662.51        1395.00
# 2 2014-11-01  00J           54     3370.70    6094.54         553.07
# 3 2014-11-01  00K            6      378.95    6354.13          59.64
# 4 2014-11-01  00L           20      866.52    6852.09         126.46
#
#    items_per_1000
# 0            1.05
# 1            5.12
# 2            8.86
# 3            0.94
# 4            2.92

# %%
#create sample deciles & prototype measure
charts.deciles_chart(
        hosp_df_1000,
        period_column='month',
        column='cost_per_1000',
        title="Hosp cost per 1000",
        show_outer_percentiles=False)

#add in example CCG (Islington)
df_subject = hosp_df_1000.loc[hosp_df_1000['pct'] == '08H']
plt.plot(df_subject['month'], df_subject['cost_per_1000'], 'r--')

plt.show()

# %%
#create sample deciles & prototype measure
charts.deciles_chart(
        hosp_df_1000,
        period_column='month',
        column='items_per_1000',
        title="Hosp items per 1000",
        show_outer_percentiles=False)

#add in example CCG (Islington)
df_subject = hosp_df_1000.loc[hosp_df_1000['pct'] == '08H']
plt.plot(df_subject['month'], df_subject['items_per_1000'], 'r--')

plt.show()

# %% [markdown]
# This will require further thought and discussion with users before deploying a measure due to noise of  antibiotics etc. Potentially we could deploy a measure on the noise is excluded?

# %%
#create choropeth map of cost per 1000 patients
plt.figure(figsize=(12, 7))
latest_hosp_df_1000 = hosp_df_1000.loc[(hosp_df_1000['month'] >= '2019-04-01') & (hosp_df_1000['month'] <= '2019-10-01')]
plt = maps.ccg_map(latest_hosp_df_1000, title="Hosp Cost per 1000 patients \n Apr - Oct 2019 ", column='cost_per_1000', separate_london=True)
plt.show()

# %%
# CCGs may like to investigate further so lets produce a file for each of them.
# here we create a dataframe csv files for each CCG to investigate further if they wish - these are now available on GitHub

ccg_investigate = df_filtered.groupby(["month", "pct", "bnf_name", "bnf_code"])["total_items","total_cost"].sum().reset_index()

# %%
#here we create the csv in a folder
    
    
        
for ccg_id, ccg_df in ccg_investigate.groupby('pct'):
     ccg_df.to_csv('ccg-data-for-review\{}.csv'.format(ccg_id), index=False)

# %% [markdown]
# ## Electronic Health Records (EHR)

# %% [markdown]
# Our recent work has show prescribing has an effect on prescribing. Theroretically EHRs could be configured to prevent "hospital only" prescribing. Indeed they may be configured this way already. Here we investigate atterns as per EHR vendor.

# %%
sql = """
SELECT
rx.month,
TRIM(Principal_Supplier) AS supplier,
rx.bnf_name,
rx.bnf_code,
SUM(items) AS total_items,
SUM(actual_cost) AS total_cost
FROM
 hscic.normalised_prescribing_standard AS rx
 JOIN (SELECT DISTINCT bnf_code 
  FROM ebmdatalab.dmd.amp
  WHERE avail_restrict = 8 AND bnf_code != '0408010F0AAABAB' AND ##clonazepam
bnf_code != '0408010F0AAACAC') AS dmd ##clonazepam
ON
  rx.bnf_code = dmd.bnf_code
JOIN
  hscic.ccgs AS ccgs
ON
  rx.pct=ccgs.code
JOIN
  alex.vendors AS software
ON
  software.ODS = rx.practice
  AND date(software.Date) = date(rx.month)
GROUP BY
rx.month,
supplier,
rx.bnf_name,
rx.bnf_code
ORDER BY
month"""



df_ehr_hosp = bq.cached_read(sql, csv_path='df_ehr_hosp.csv')
df_ehr_hosp['month'] = df_ehr_hosp['month'].astype('datetime64[ns]')
df_ehr_hosp.head(3)
# Out:
#        month supplier                                  bnf_name  \
# 0 2016-01-01     EMIS  Promixin_Inj 1 000 000u Vl (Dry)
# 1 2016-01-01     INPS  Daptomycin_I/V Inf 500mg Vl (Dry)
# 2 2016-01-01     EMIS  Pantoprazole_Inj 40mg Vl
#
#           bnf_code  total_items  total_cost
# 0  0501070I0BCABAB            1       55.43
# 1  0501070Y0AAABAB            1      572.63
# 2  0103050R0AAACAC            1      132.16

# %%
sql = '''
WITH presentations_with_some_hospital_only_amps AS (
  SELECT bnf_code
  FROM dmd.amp
  WHERE avail_restrict = 8 and avail_restrict !=9 AND bnf_code IS NOT NULL ##8 relates to hospital only in dmd
  
  UNION DISTINCT 
  
  SELECT vmp.bnf_code
  FROM dmd.vmp
  INNER JOIN dmd.amp
    ON vmp.id = amp.vmp
  WHERE amp.avail_restrict = 8 AND vmp.bnf_code IS NOT NULL
)

SELECT
  TRIM(Principal_Supplier) AS supplier,
  month,
  presentation AS bnf_name,
  bnf_code,
  SUM(items) AS total_items,
  SUM(actual_cost) AS total_cost
FROM
  hscic.normalised_prescribing_standard AS rx
INNER JOIN
  hscic.ccgs
ON
  rx.pct = ccgs.code
INNER JOIN
  hscic.bnf
ON
  rx.bnf_code = bnf.presentation_code
INNER JOIN
  alex.vendors AS software
ON
  software.ODS = rx.practice
  AND date(software.Date) = date(rx.month)
WHERE
  org_type = 'CCG'
  AND bnf_code IN (SELECT bnf_code FROM presentations_with_some_hospital_only_amps) 
  AND bnf_code NOT LIKE "0703021Q0AA%" #desogestrel
  AND bnf_code NOT LIKE "0408010F0AA%" #clonazepam 
  AND bnf_code NOT LIKE "0704050R0AA%" #tadalafil
  AND bnf_code NOT LIKE "0406000S0AA%" #ondansetron
GROUP BY
  supplier,
  month,
  bnf_code,
  bnf_name
ORDER BY
  supplier,
  month,
  bnf_code
'''


df_ehr_hosp_only = bq.cached_read(sql, csv_path='df_ehr_hosp_only.csv', use_cache=True)
df_ehr_hosp_only['month'] = df_ehr_hosp_only['month'].astype('datetime64[ns]')
df_ehr_hosp_only.head()
# Out:
#   supplier      month                                bnf_name  \
# 0     EMIS 2016-01-01              Omeprazole_I/V Inf 40mg Vl
# 1     EMIS 2016-01-01                Pantoprazole_Inj 40mg Vl
# 2     EMIS 2016-01-01    Tranexamic Acid_Inj 100mg/ml 5ml Amp
# 3     EMIS 2016-01-01  Chlorphenamine Mal_Inj 10mg/ml 1ml Amp
# 4     EMIS 2016-01-01     Zuclopenth Acet_Inj 50mg/ml 1ml Amp
#
#           bnf_code  total_items  total_cost
# 0  0103050P0AAAVAV            2      348.11
# 1  0103050R0AAACAC            1      132.16
# 2  0211000P0AAAAAA           32     1623.77
# 3  0304010G0AAAAAA           35     2610.57
# 4  040201010AAAAAA            6       90.00

# %%
##groupby bnf name  to see "biggest offenders" in terms of items
df_product_ehr = df_ehr_hosp_only.groupby(['bnf_code', 'bnf_name']).sum().sort_values(by = 'total_items', ascending = False)
df_product_ehr
# Out:
#                                                           total_items  \
# bnf_code        bnf_name
# 0407020ADAAALAL Oxycodone HCl_Inj 10mg/ml 1ml Amp               88029
# 0501070I0AAABAB Colistimeth Sod_Inj 1,000,000u Vl               15675
# 0407020ADAAAMAM Oxycodone HCl_Inj 10mg/ml 2ml Amp               13783
# 0407020ADAAANAN Oxycodone HCl_Inj 50mg/ml 1ml Amp               11388
# 1501041T0AAABAB Midazolam HCl_Inj 2mg/ml 5ml Amp                 9173
# 0304010G0AAAAAA Chlorphenamine Mal_Inj 10mg/ml 1ml Amp           3922
# 1501043A0AAADAD Alfentanil HCl_Inj 5mg/ml 1ml Amp                3800
# 0211000P0AAAAAA Tranexamic Acid_Inj 100mg/ml 5ml Amp             2317
# 0501021G0AAADAD Ceftriaxone Sod_Inj 2g Vl                        2297
# 0501040H0AAAMAM Gentamicin Sulf_Inj 40mg/ml 2ml Vl               2221
# 0501021G0AAACAC Ceftriaxone Sod_Inj 1g Vl                        2060
# 0704050B0BCAIBN Viridal Duo_S/Pack Inj 40mcg Cart                1632
# 0704050B0BCAGBL Viridal Duo_S/Pack Inj 20mcg Cart                1317
# 0704050B0BCAHBM Viridal Duo_S/Pack Inj 10mcg Cart                1187
# 0408010A0AAAJAJ Levetiracetam_I/V Inf 100mg/ml 5ml Vl            1174
# 0704050B0AABNBN Alprostadil_S/Pack Inj 40mcg Cart                 832
# 1501042E0AAAAAA Ketorolac Trometamol_Inj 30mg/ml 1ml Amp          745
# 0501013C0AAADAD Amoxicillin Sod_Inj 500mg Vl                      732
# 0501022B0AAAAAA Ertapenem Sod_I/V Inf 1g Vl (Dry)                 693
# 1405010A0AAACAC Hum Nor Imglob_I/V Inf 5% 10g/200ml Vl        354.46
# 0501120X0AAADAD Levofloxacin_I/V Inf 5mg/ml 100ml Bag          18.71
# 0203020D0AAADAD Amiodarone HCl_Inj 50mg/ml 3ml Amp              8.92
# 1108020ADBBABAB Lucentis_Inj 10mg/ml 0.23ml Vl                686.74
# 0801050AMAAACAC Sunitinib_Cap 50mg                            104.19
# 0502040A0AAABAB Anidulafungin_I/V Inf Pdr 100mg Vl           1587.15
# 0701010T0BBACAC Syntocinon_Inj 10u/1ml Amp                      0.96
# 0801050AMAAAAAA Sunitinib_Cap 12.5mg                         2180.57
# 0801030W0BBAAAA Fludara_Tab 10mg                              131.14
# 0801030H0AAARAR Fluorouracil_Inj 50mg/ml 10ml Vl               11.85
# 0801050CBAAACAC Palbociclib_Cap 125mg                        2740.73
# 0801020R0AAAAAA Mitoxantrone_Inj 2mg/ml 10ml Vl               112.78
# 0802030F0AAAAAA Rituximab_I/V Inf 10mg/ml 50ml Vl             808.11
# 0801010H0AAADAD Cyclophosphamide_Inj 1g Vl                     15.80
# 0802040W0AAAAAA Natalizumab_I/V Inf 20mg/ml 15ml Vl          1046.91
# 0704050R0BDAAAB Talmanco_Tab 20mg                             387.55
# 0205010Y0AAACAC Sildenafil_Inj 800mcg/ml 12.5ml Vl            336.45
# 0901060P0AAAAAA Pegfilgrastim_Inj 10mg/ml 0.6ml Pfs           635.43
# 0701010T0AAABAB Oxytocin_Inj 5u/ml 1ml Amp                     83.34
# 0801050AMAAABAB Sunitinib_Cap 25mg                           1458.50
# 0908010ACAAAAAA Miglustat_Cap 100mg                          7827.15
# 0908010AHBBAAAA Myozyme_I/V Inf 50mg Vl (Dry)                1319.32
# 0701010I0BBAFAF Prostin_E2 Gel 1mg/2.5ml Pfs                   12.34
# 1001010Q0AAACAC Phenylbutazone_Tab 200mg                       53.12
# 0606020P0AAAJAJ Pamidronate Disod_I/V Inf 3mg/ml 10ml Vl      110.41
# 0606020P0AAAIAI Pamidronate Disod_I/V Inf 3mg/ml 5ml Vl        25.53
# 0606020P0AAAHAH Pamidronate Disod_I/V Inf 9mg/ml 10ml Vl      157.44
# 0605010Z0BBAAAA Somavert_Inj 10mg Vl + Dil                    231.81
# 0503021B0AAAAAA Aciclovir Sod_Inf I/V 250mg Vl (Dry)           15.47
# 0503010D0AAACAC Efavirenz_Cap 50mg                              0.63
# 1001030D0AAAGAG Etanercept_Inj 50mg/ml 0.5ml Pf Pen           331.16
# 0503021C0AAAIAI Aciclovir_I/V Inf 25mg/ml 10ml Vl              27.84

# %%
df_ehr_hosp_only.groupby(['month', 'supplier']).sum()['total_items'].unstack().plot.line()
plt.legend(loc=(1.04,0))
plt.title("total hosp only items per EHR vendor")
# Out:
# Text(0.5, 1.0, 'total hosp only items per EHR vendor')

# %% [markdown]
# There is no striking trend but the downwar trend in overall prescribing came circa 2016 and we only have EHR data until 2016. We should speak to EHR vendors, nerds and NHS Digital about this.  We should have a look at user interface to support further work.
