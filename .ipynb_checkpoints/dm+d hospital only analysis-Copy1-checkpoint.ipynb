# %% [markdown]
# The [NHS dictionary of medicines and devices (dm+d)](https://ebmdatalab.net/what-is-the-dmd-the-nhs-dictionary-of-medicines-and-devices/) has a flags to indicate as to whether a given item should be made available through hospital prescribing [(see tech spec of dm+d)](https://www.nhsbsa.nhs.uk/sites/default/files/2017-02/Data_Model_R2_v3.1_May_2015.pdf). We have [previously investigated some of the hospital flags](https://github.com/ebmdatalab/jupyter-notebooks/blob/3dc1f0d45173ab2dcf3156848df65e7a54be40f2/new_measures/Drafts/Hospital/Primary%20Care%20Prescribing%20of%20%20Hospital%20%20Only%20Medicines.ipynb).
#
# During our [work on zuclopenthixol](https://ebmdatalab.net/zuclopenthixol-acetate-a-new-kind-of-measure-on-openprescribing/) it became apparent that despite being a "hospital only" medicine, it was classified as such and is perhaps being administered inappropriately in primary care.
#
# Building on previous work this notebook sets out to explore primary care prescribing of "hospital only" medicines as defined by the [NHS dm+d](https://ebmdatalab.net/what-is-the-dmd-the-nhs-dictionary-of-medicines-and-devices/)

# %%
#import libraries required for analysis
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from ebmdatalab import bq
from ebmdatalab import charts
from ebmdatalab import maps

# %%
sql = '''
WITH presentations_with_some_hospital_only_amps AS (
  SELECT bnf_code
  FROM dmd.amp
  WHERE avail_restrict = 8 and avail_restrict !=9 AND bnf_code IS NOT NULL ##8 relates to hospital only in dmd
  
  UNION DISTINCT 
  
  SELECT vmp.bnf_code
  FROM dmd.vmp
  INNER JOIN dmd.amp
    ON vmp.id = amp.vmp
  WHERE amp.avail_restrict = 8 AND vmp.bnf_code IS NOT NULL
)

SELECT
  pct,
  month,
  presentation AS bnf_name,
  bnf_code,
  SUM(items) AS total_items,
  SUM(actual_cost) AS total_cost
FROM
  hscic.normalised_prescribing_standard AS rx
INNER JOIN
  hscic.ccgs
ON
  rx.pct = ccgs.code
INNER JOIN
  hscic.bnf
ON
  rx.bnf_code = bnf.presentation_code
WHERE
  org_type = 'CCG'
  AND bnf_code IN (SELECT bnf_code FROM presentations_with_some_hospital_only_amps) 
GROUP BY
  pct,
  month,
  bnf_code,
  bnf_name
ORDER BY
  pct,
  month,
  bnf_code'''


df_hospital = bq.cached_read(sql, csv_path='data/df_hospital.csv', use_cache=True)
df_hospital['month'] = df_hospital['month'].astype('datetime64[ns]')
df_hospital.head()
# Out:
#    pct      month                             bnf_name         bnf_code  \
# 0  00C 2010-08-01  Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA
# 1  00C 2010-08-01              Ondansetron HCl_Tab 8mg  0406000S0AAACAC
# 2  00C 2010-08-01                Clonazepam_Tab 500mcg  0408010F0AAABAB
# 3  00C 2010-08-01                   Clonazepam_Tab 2mg  0408010F0AAACAC
# 4  00C 2010-08-01                Desogestrel_Tab 75mcg  0703021Q0AAAAAA
#
#    total_items  total_cost
# 0            1       10.01
# 1            8      718.58
# 2          107      179.18
# 3            9       26.08
# 4           11       77.50

# %%
df_hospital.nunique()
# Out:
# pct               193
# month             111
# bnf_name          301
# bnf_code          301
# total_items      2129
# total_cost     157568
# dtype: int64

# %%
df_hospital["bnf_name"].unique()
# Out:
# array(['Zuclopenth Acet_Inj 50mg/ml 1ml Amp', 'Ondansetron HCl_Tab 8mg',
#        'Clonazepam_Tab 500mcg', 'Clonazepam_Tab 2mg',
#        'Desogestrel_Tab 75mcg', 'Tadalafil_Tab 20mg',
#        'Midazolam HCl_Inj 2mg/ml 5ml Amp',
#        'Lido HCl/Adren (Base)_Inj 1% 20ml Vl',
#        'Xylocaine + Adren_Inj 1% 20ml Vl',
#        'Tranexamic Acid_Inj 100mg/ml 5ml Amp',
#        'Oxycodone HCl_Inj 10mg/ml 1ml Amp',
#        'Colistimeth Sod_Inj 1,000,000u Vl',
#        'Gentamicin Sulf_Inj 40mg/ml 2ml Vl',
#        'Oxycodone HCl_Inj 10mg/ml 2ml Amp',
#        'Chlorphenamine Mal_Inj 10mg/ml 1ml Amp',
#        'Oxycodone HCl_Inj 50mg/ml 1ml Amp',
#        'Alfentanil HCl_Inj 5mg/ml 1ml Amp',
#        'Methotrexate_Inj 2.5mg/ml 2ml Vl', 'Ceftriaxone Sod_Inj 250mg Vl',
#        'Levobupivac HCl_Inj 2.5mg/ml 10ml Amp',
#        'Ketamine_Inj 50mg/ml 10ml Vl', 'Amoxicillin Sod_Inj 500mg Vl',
#        'Fluclox Sod_Inj 250mg Vl', 'Viridal Duo_S/Pack Inj 20mcg Cart',
#        'Amikacin_Inj 250mg/ml 2ml Vl',
#        'B.C.G._Blad Instillation 12.5mg Vl',
#        'Ketorolac Trometamol_Inj 30mg/ml 1ml Amp',
#        'Ertapenem Sod_I/V Inf 1g Vl (Dry)',
#        'Rituximab_I/V Inf 10mg/ml 10ml Vl',
#        'Zoledronic Acid_I/V Inf 40mcg/ml 100ml',
#        'Dexameth Sod Phos Base_Inj 3.8mg/ml1mlVl',
#        'Posaconazole_Oral Susp 200mg/5ml',
#        'Levetiracetam_I/V Inf 100mg/ml 5ml Vl',
#        'Viridal Duo_S/Pack Inj 40mcg Cart',
#        'Vancomycin HCl_I/V Inf 500mg Vl',
#        'Daptomycin_I/V Inf 500mg Vl (Dry)', 'Pantoprazole_Inj 40mg Vl',
#        'Ceftriaxone Sod_Inj 2g Vl', 'Ceftriaxone Sod_Inj 1g Vl',
#        'Viridal Duo_S/Pack Inj 10mcg Cart',
#        'Fondaparinux Sod_Inj 12.5mg/ml 0.6ml Pfs',
#        'Cefuroxime Sod_Inj 750mg Vl',
#        'Marcain_Plain Inj 0.5% 10ml Polyamp',
#        'Meropenem_Inj 500mg Vl (Dry)',
#        'Alprostadil_S/Pack Inj 20mcg Cart',
#        'Ceftazidime Pentahyd_Inj 1g Vl',
#        'Linezolid_I/V Inf 2mg/ml 300ml Bag',
#        'Etanercept_Inj 50mg/ml 1ml Pf Pen',
#        'Enbrel_Inj 50mg/ml 1ml Pf MyClic Pen', 'Nutricia_preOp Liq',
#        'Metoprolol Tart_Inj 1mg/ml 5ml Amp',
#        'Vancomycin HCl_I/V Inf 1g Vl', 'Phenylbutazone_Tab 100mg',
#        'Gefitinib_Tab 250mg', 'Methotrexate_Inj 25mg/ml 2ml Vl',
#        'Botox_Inj 100u Vl', 'Daptomycin_I/V Inf 350mg Vl (Dry)',
#        'OncoTICE_Blad Instillation 12.5mg Vl',
#        'Etanercept_Inj 25mg Vl + Dil', 'Abatacept_Inj 125mg/1ml Pfs',
#        'Ondemet_Tab 8mg', 'Zoledronic Acid_I/V Inf 40mcg/ml 100mlVl',
#        'Marcain_Heavy Inj 4ml Amp', 'Isavuconazole_Cap 100mg',
#        'Piperacillin/Tazobactam_I/VInf 4g/0.5gVl',
#        'Meropenem_Inj 1g Vl (Dry)',
#        'Rapifen Intensive Care_Inj 5mg/1ml Amp',
#        'Alprostadil_S/Pack Inj 10mcg Cart', 'Tofacitinib_Tab 5mg',
#        'Zoledronic Acid_I/V Inf 800mcg/ml 5ml Vl',
#        'Bupivac HCl_Inj 0.5% 50mg/10ml Amp', 'Amoxicillin Sod_Inj 1g Vl',
#        'Etanercept_Inj 25mg/0.5ml Pfs', 'Cefotaxime Sod_Inj 1g Vl',
#        'Co-Amoxiclav_Inj 1g/200mg Vl', 'Etanercept_Inj 50mg/1ml Pfs',
#        'Piperacillin/Tazobactam_I/VInf2g/0.25gVl',
#        'Toradol_Inj 30mg/ml 1ml Amp', 'Ceftazidime Pentahyd_Inj 2g Vl',
#        'Etanercept_Inj 10mg Vl + Dil', 'Co-Amoxiclav_Inj 500mg/100mg Vl',
#        'Emtricitabine/Tenofovir_Tab 200mg/245mg',
#        'Fluclox Sod_Inj 500mg Vl', 'Amoxicillin Sod_Inj 250mg Vl',
#        'Chirocaine_Inj 2.5mg/ml 10ml Amp', 'Fluclox Sod_Inj 1g Vl',
#        'Alprostadil_S/Pack Inj 40mcg Cart', 'Enbrel_Inj 50mg/ml Pfs',
#        'Infliximab_Inf 100mg Vl', 'Abacavir/Lamivudine_Tab 600mg/300mg',
#        'Cyclophosphamide_Inj 1g Vl', 'Cefotaxime Sod_Inj 500mg Vl',
#        'Arixtra_Inj 7.5mg/0.6ml Pfs', 'Botox_Inj Pdr 50u Vl',
#        'Aciclovir Sod_Inf I/V 500mg Vl (Dry)', 'Phenylbutazone_Tab 200mg',
#        'Bupivac HCl/Glucose_Inj 5mg/80mg/ml 4ml',
#        'Syntocinon_Inj 10u/1ml Amp', 'Ibuprofen_Inj 5mg/ml 2ml Amp',
#        'Fondaparinux Sod_Inj 5mg/ml 0.3ml Pfs',
#        'Clopixol Acuphase_Inj 50mg/ml 1ml Amp',
#        'Cefuroxime Sod_Inj 250mg Vl', 'Efavirenz_Tab 600mg',
#        'Misoprostol_Tab 400mcg', 'Tolvaptan_Tab 15mg',
#        'Miglustat_Cap 100mg', 'Fludarabine Phos_Tab 10mg',
#        'Ceftazidime Pentahyd_Inj 500mg Vl',
#        'Atenolol_Inj 500mcg/ml 10ml Amp',
#        'Levobupivac HCl_Inj 5mg/ml 10ml Amp',
#        'Chirocaine_Inj 5mg/ml 10ml Amp',
#        'Clarithromycin_I/V Inf 500mg Vl',
#        'Zinacef_I/M/I/V 750mg Vl (Dry)',
#        'Clindamycin Phos_Inj 150mg/ml 4ml Amp',
#        'Clindamycin Phos_Inj 150mg/ml 2ml Amp',
#        'Tocilizumab_I/V Inf 80mg/4ml Vl', 'Aztreonam_Inj 2g Vl',
#        'Erythromycin_Lactobi I/V Inf 1g Vl', 'Cefuroxime Sod_Inj 1.5g Vl',
#        'Methotrexate_Inj 25mg/ml 20ml Vl',
#        'Betaferon_Inj 300mcg Vl + Dil', 'Ceftazidime Pentahyd_Inj 3g Vl',
#        'Enbrel_Inj 25mg Vl + Dil', 'Tigecycline_I/V Inf 50mg Vl (Dry)',
#        'Enbrel_Inj 25mg/0.5ml Pfs', 'Tocilizumab_Inj 162mg/0.9ml Pfs',
#        'Revatio_Inj 800mcg/ml 12.5ml Vl', 'Orencia_Inj 125mg/1ml Pfs',
#        'Promixin_Inj 1,000,000u Vl (Dry)',
#        'Calc Folinate_Inj 7.5mg/ml 2ml Amp', 'Aztreonam_Inj 1g Vl',
#        'Syntocinon_Inj 5u/1ml Amp', 'Omeprazole_I/V Inf 40mg Vl',
#        'Pegvisomant_Inj 10mg Vl + Dil', 'Capecitabine_Tab 500mg',
#        'Adenosine_I/V Inf 3mg/ml 2ml Vl',
#        'Adenocor_I/V Inf 3mg/ml 2ml Vl', 'Somavert_Inj 20mg Vl + Dil',
#        'Enoximone_Inj 5mg/ml 20ml Amp', 'Perfan_Inj 5mg/ml 20ml Amp',
#        'Botulinum A Toxin_Inj Pdr 100u Vl', 'Metvix_Crm 16%',
#        'Methyl-5-Aminolevulinate_Crm 16%',
#        'Trastuzumab_I/V Inf 150mg Vl (Dry)',
#        'Adren_Inj 1/10,000 10ml Pfs', 'Sutent_Cap 12.5mg',
#        'Sutent_Cap 25mg', 'Caffeine Cit_Inj 20mg/ml 1ml Amp',
#        'Methotrexate_Inj 100mg/ml 10ml Vl',
#        'Fortum_I/M Or I/V Inj 1g Vl (Dry)',
#        'Ciproxin_I/V Inf 2mg/ml 100ml Btl', 'Sunitinib_Cap 12.5mg',
#        'Oxytocin_Inj 10u/ml 1ml Amp', 'Ciproxin_I/V Inf 2mg/ml 200ml Btl',
#        'Aciclovir Sod_Inf I/V 250mg Vl (Dry)', 'Atazanavir_Cap 150mg',
#        'Pegfilgrastim_Inj 10mg/ml 0.6ml Pfs', 'Sunitinib_Cap 50mg',
#        'Flumazenil_Inj 100mcg/ml 5ml Amp',
#        'Ibandronic Acid_I/V Inf 1mg/ml 2ml Vl',
#        'Cubicin_I/V Inf 500mg Vl (Dry)',
#        'Phenytoin_Sod Inj 50mg/ml 5ml Amp', 'Mag Sulf_Inj 10% 10ml Amp',
#        'Fortum_I/M Or I/V Inj 500mg Vl (Dry)', 'Viramune_Tab 100mg M/R',
#        'Arixtra_Inj 1.5mg/0.3ml Pfs',
#        'Danaparoid Sod_Inj 1,250u/ml 0.6ml Amp',
#        'Ciprofloxacin_I/V Inf 2mg/ml 200ml Btl',
#        'Temocillin Sod_Inj 1g Vl', 'Fortum_I/V Inj/Inf 3g Vl (Dry)',
#        'Esomeprazole_Inj 40mg Vl (Dry)', 'Fampridine_Tab 10mg M/R',
#        'Ciprofloxacin_I/V Inf 2mg/ml 200ml Bag',
#        'Cubicin_I/V Inf 350mg Vl (Dry)',
#        'Alprostadil_I/V Inf 500mcg/ml 1ml Amp', 'Tolvaptan_Tab 30mg',
#        'Jinarc_Tab 15mg', 'Temozolomide_Cap 100mg',
#        'Temozolomide_Cap 20mg', 'Tysabri_I/V Inf 300mg/15ml Vl',
#        'RoActemra_Conc For Inf 80mg/4ml Vl',
#        'Rituximab_I/V Inf 10mg/ml 50ml Vl',
#        'Ranibizumab_Inj 10mg/ml 0.23ml Vl', 'Atazanavir_Cap 300mg',
#        'Ofev_Cap 100mg', 'Aciclovir_I/V Inf 25mg/ml 10ml Vl',
#        'Zoledronic Acid_I/V Inf 50mcg/ml 100mlVl',
#        'Hum Nor Imglob_I/V Inf 5% 10g/200ml Vl',
#        'Hum Nor Imglob_I/V Inf 5% 5g/100ml Vl',
#        'Paracet_I/V Inf 10mg/ml 50ml Btl', 'Nintedanib_Cap 100mg',
#        'Lucentis_Inj 10mg/ml 0.23ml Vl',
#        'Tocilizumab_I/V Inf 200mg/10ml Vl',
#        'Labetalol HCl_Inj 5mg/ml 20ml Amp',
#        'Ciprofloxacin_I/V Inf 2mg/ml 100ml Bag',
#        'Glyceryl Trinit_Inj 5mg/ml 5ml Amp',
#        'Natalizumab_I/V Inf 20mg/ml 15ml Vl',
#        'Zoledronic Acid_I/V Inf 50mcg/ml 100ml',
#        'Noxafil_Oral Susp 40mg/ml', 'Reyataz_Cap 150mg',
#        'Temozolomide_Cap 180mg', 'Ethanol_Inj 100% 2ml Amp',
#        'Sustiva 600_Tab 600mg', 'Negaban_Inj 1g Vl',
#        'Botox_Inj Pdr 200u Vl', 'Botulinum A Toxin_Inj Pdr 50u Vl',
#        'Mepolizumab_Inj 100mg Vl (Dry)',
#        'Gentamicin Sulf_Inj 5mg/ml 1ml Amp', 'Nintedanib_Cap 150mg',
#        'Talmanco_Tab 20mg', 'Nexium I.V._Inj 40mg Vl (Dry)',
#        'Sunitinib_Cap 25mg', 'Netupitant/Palonosteron_Cap 300mg/500mcg',
#        'Inflectra_Inf 100mg Vl', 'Atracurium Besil_Inj 10mg/ml 2.5ml Amp',
#        'Axitinib_Tab 5mg', 'RoActemra_Inj 162mg/0.9ml Pfs',
#        'Erelzi_Inj 50mg/ml 1ml Pf Pen',
#        'Sildenafil_Inj 800mcg/ml 12.5ml Vl', 'Fortum_I/V Inj 2g Vl (Dry)',
#        'Carboplatin_I/V Inf 10mg/ml 15ml Vl',
#        'Ropivacaine HCl_Inj 7.5mg/ml 10ml Amp',
#        'Ciprofloxacin_I/V Inf 2mg/ml 100ml Btl',
#        'Azactam_Inj 1g Vl (Dry)', 'Gelatin_I/V Inf 4% 500ml',
#        'Dalacin C Phos_Inj 150mg/ml 4ml Amp',
#        'Pegvisomant_Inj 15mg Vl + Dil',
#        'Voriconazole_I/V Inf 200mg Vl (Dry)',
#        'Lumacaftor/Ivacaftor_Tab 200mg/125mg',
#        'Interf B 1b_Inj 300mcg Vl + Dil', 'Prostin_E2 Gel 1mg/2.5ml Pfs',
#        'Remicade_Inf 100mg Vl', 'Pegvisomant_Inj 20mg Vl + Dil',
#        'Levofloxacin_I/V Inf 5mg/ml 100ml Vl', 'Dabrafenib_Cap 75mg',
#        'Moxifloxacin_I/V Inf 1.6mg/ml 250ml Btl',
#        'Pamidronate Disod_I/V Inf 9mg/ml 10ml Vl', 'Temodal_Cap 5mg',
#        'Tygacil_I/V Inf 50mg Vl (Dry)', 'Ofev_Cap 150mg',
#        'Ciprofloxacin_I/V Inf 2mg/ml 50ml Btl',
#        'Calc Folinate_Inj 10mg/ml 10ml Vl',
#        'Calc Folinate_Inj 10mg/ml 30ml Vl',
#        'Calc Folinate_Inj 10mg/ml 5ml Vl', 'Remsima_Inf 100mg Vl',
#        'Ibandronic Acid_I/V Inf 1mg/ml 6ml Vl',
#        'Mycophenolate Mofetil_Inj 500mg Vl', 'Nevirapine_Tab 100mg M/R',
#        'Sustiva_Cap 200mg', 'Somavert_Inj 10mg Vl + Dil',
#        'Fluorouracil_Inj 50mg/ml 10ml Vl',
#        'Octagam_I/V Inf 10% 10g/100ml Btl', 'Atazanavir_Cap 200mg',
#        'Eptifibatide_I/V Inf 750mcg/ml 100ml Vl', 'Efavirenz_Cap 50mg',
#        'Fampyra_Tab 10mg M/R', 'Cisatracurium_Inj 2mg/ml 10ml Amp',
#        'NeuroBloc_Inj 5,000u/ml 1ml Vl',
#        'Anidulafungin_I/V Inf Pdr 100mg Vl',
#        'Pancuronium Brom_Inj 2mg/ml 2ml Amp',
#        'Botulinum A Toxin_Inj Pdr 200u Vl', 'Efavirenz_Cap 200mg',
#        'Ciproxin_I/V Inf 2mg/ml 50ml Btl', 'Sutent_Cap 50mg',
#        'Pamidronate Disod_I/V Inf 3mg/ml 5ml Vl',
#        'Abatacept_I/V Inf 250mg Vl (Dry)',
#        'Pegvisomant_Inj 30mg Vl + Dil', 'Mitomycin_Inj 20mg Vl',
#        'Hum Nor Imglob_I/V Inf 5g/50ml Vl',
#        'Hum Nor Imglob_I/V Inf 10g/100ml Vl',
#        'Hum Nor Imglob_I/V Inf 20g/200ml Vl',
#        'Chirocaine_Inj 7.5mg/ml 10ml Amp',
#        'Levobupivac HCl_Inj 7.5mg/ml 10ml Amp',
#        'Levofloxacin_I/V Inf 5mg/ml 100ml Bag',
#        'Mitoxantrone_Inj 2mg/ml 10ml Vl',
#        'Etanercept_Inj 50mg/ml 0.5ml Pf Pen',
#        'Oxytocin_Inj 5u/ml 1ml Amp', 'Temozolomide_Cap 5mg',
#        'Temozolomide_Cap 140mg', 'Volplex_I/V Inf 4% 500ml',
#        'Myozyme_I/V Inf 50mg Vl (Dry)', 'Fluclox Sod_Inj 2g Vl',
#        'Tracrium_Inj 10mg/ml 5ml Amp', 'Fludara_Tab 10mg',
#        'Bupivac/Fentanyl_Inf 250mg/500mcg/250ml',
#        'Aciclovir_I/V Inf 25mg/ml 20ml Vl',
#        'Gelaspan_Ecobag I/V Inf 4% 500ml',
#        'Amiodarone HCl_Inj 50mg/ml 3ml Amp',
#        'RoActemra_Conc For Inf 200mg/10ml Vl',
#        'Docetaxel_I/V Inf 20mg/1ml Vl',
#        'Fluconazole_I/V Inf 2mg/ml 100ml Bag',
#        'Cyclophosphamide_Inj 500mg Vl', 'Palbociclib_Cap 125mg',
#        'Ustekinumab_I/V Inf 5mg/ml 26ml Vl',
#        'Pamidronate Disod_I/V Inf 3mg/ml 10ml Vl', 'Axitinib_Tab 7mg',
#        'Cytarabine_Inj 100mg/ml 10ml Vl', 'Ultiva_Inj 1mg Vl (Dry)',
#        'Epanutin_Inj 50mg/ml 5ml Amp', 'Akynzeo_Cap 300mg/0.5mg',
#        'Botulinum B Toxin_Inj 5,000u/ml 0.5ml Vl'], dtype=object)

# %% [markdown]
# There are 290 unique names but at a glance they seem to be overwhelmingly what we would expect to be "hospital only" medicines. However many are for iv antibiotics and some other medicines where some areas have pioneered the use of specialist communiyt teams to adminster medicines in a patients own home to avoid a hospital admission. These may no longer be truly "hospital only".

# %%
##groupby bnf name  to see "biggest offenders" in terms of items
df_product = df_hospital.groupby(['bnf_code', 'bnf_name']).sum().sort_values(by = 'total_items', ascending = False).reset_index()
df_product.head(25)
# Out:
#            bnf_code                                  bnf_name  total_items  \
# 0   0703021Q0AAAAAA                     Desogestrel_Tab 75mcg      8712329
# 1   0408010F0AAABAB                     Clonazepam_Tab 500mcg      6645674
# 2   0704050R0AAABAB                        Tadalafil_Tab 20mg      3347874
# 3   0408010F0AAACAC                        Clonazepam_Tab 2mg       976242
# 4   1502010J0BBAXAY          Xylocaine + Adren_Inj 1% 20ml Vl       526215
# 5   1502010J0AAAYAY      Lido HCl/Adren (Base)_Inj 1% 20ml Vl       219821
# 6   0406000S0AAACAC                   Ondansetron HCl_Tab 8mg       203372
# 7   0407020ADAAALAL         Oxycodone HCl_Inj 10mg/ml 1ml Amp       176474
# 8   1502010C0BBAJAD       Marcain_Plain Inj 0.5% 10ml Polyamp        55930
# 9   0501070I0AAABAB         Colistimeth Sod_Inj 1,000,000u Vl        44048
# 10  1501041T0AAABAB          Midazolam HCl_Inj 2mg/ml 5ml Amp        36619
# 11  0407020ADAAAMAM         Oxycodone HCl_Inj 10mg/ml 2ml Amp        32949
# 12  0407020ADAAANAN         Oxycodone HCl_Inj 50mg/ml 1ml Amp        29043
# 13  1502010C0AAADAD        Bupivac HCl_Inj 0.5% 50mg/10ml Amp        14263
# 14  0304010G0AAAAAA    Chlorphenamine Mal_Inj 10mg/ml 1ml Amp        11583
# 15  1501043A0AAADAD         Alfentanil HCl_Inj 5mg/ml 1ml Amp         9508
# 16  0501021G0AAACAC                 Ceftriaxone Sod_Inj 1g Vl         8343
# 17  0501021G0AAADAD                 Ceftriaxone Sod_Inj 2g Vl         7982
# 18  0501040H0AAAMAM        Gentamicin Sulf_Inj 40mg/ml 2ml Vl         6892
# 19  0208010ABAAACAC  Fondaparinux Sod_Inj 12.5mg/ml 0.6ml Pfs         5426
# 20  0211000P0AAAAAA      Tranexamic Acid_Inj 100mg/ml 5ml Amp         4718
# 21  0603020H0AAALAL  Dexameth Sod Phos Base_Inj 3.8mg/ml1mlVl         4002
# 22  1502010C0BBAHAK                 Marcain_Heavy Inj 4ml Amp         3784
# 23  0501022B0AAAAAA         Ertapenem Sod_I/V Inf 1g Vl (Dry)         3288
# 24  0704050B0BCAIBN         Viridal Duo_S/Pack Inj 40mcg Cart         2832
#
#       total_cost
# 0   4.058849e+07
# 1   4.237827e+07
# 2   1.038738e+08
# 3   5.511789e+06
# 4   1.420275e+06
# 5   5.351588e+05
# 6   9.653056e+06
# 7   3.159319e+06
# 8   1.351441e+05
# 9   4.536934e+06
# 10  2.524284e+05
# 11  1.775587e+06
# 12  6.553966e+06
# 13  3.175697e+04
# 14  5.210781e+05
# 15  4.772398e+05
# 16  4.413019e+05
# 17  1.080849e+06
# 18  4.859061e+05
# 19  1.131001e+06
# 20  1.307611e+05
# 21  8.981567e+04
# 22  1.173741e+04
# 23  7.725653e+05
# 24  1.714576e+05

# %% [markdown]
# Some comments
# - desogesterel is definitely not a hospital only medicine. It is a commonly used contraceptive. The [brand Moonia](https://openprescribing.net/dmd/amp/36546611000001102/) has been classed as hospital only and affects the figures.
# - Clonazepam would not be considered a "hospital only" medicine. Reviewing dm+d it appears that a [product by Star Pharmaceuticals](https://openprescribing.net/dmd/advanced-search/amp/?search=%5B%22and%22%2C%5B%5B%22nm%22%2C%22contains%22%2C%22clonazep%22%5D%2C%5B%22avail_restrict%22%2C%22equal%22%2C%228%22%5D%5D%5D) has been designated "hospital only" while all other clonazepam products are not. I can't find the SPC for Star Pharmaceutical to see if there is some licnese difference but it is likely that this is a misclassification.
# - Colistimeth Sod: This is used iv but also inhaled in treatment of lung infections particularly Cystic Fibrosis. [NHS England states](https://www.england.nhs.uk/wp-content/uploads/2019/04/nhs-england-drugs-list-v14.1.pdf) that when used for treatment of infections related to Cystic Fibrosis it is suiatable for shared care i.e. a GP could prescribe on FP10.
# Reviewing the [	Colistimethate 1million unit powder for solution for injection vials](https://openprescribing.net/dmd/vmp/324311004/)  AMPs more closely we find differences in the designations dependent on product.
#
# | AMP  | Hospital Only   |
# |------|-----------------|
# | [Colomycin](https://openprescribing.net/dmd/amp/3108611000001108/)*| No|
# |[Promixin](https://openprescribing.net/dmd/amp/4658711000001106/) | Yes|
# |[Kent Pharm](https://openprescribing.net/dmd/amp/17652211000001105/) | Yes|
# |[AAH](https://openprescribing.net/dmd/amp/18758011000001102/)** | No |
#
#         *The IV produc also has a license to be used by inhalation
#         ** Most likely a make believe wholesaler product
#
# - Antibiotics: The list is mainly antibiotics or palliatve care medicines. We do see these medicines in the community nowadays as the NHS seeks to keep people out of hospital. Potentially it is inapprorpriate to label these medicines "hospital only".
#
# **Conclusion**
# 1 - We must investigate which products that are "mixed" i.e. should be excluded as it looks like an error in classification e.g. clonazepam and which should be retained for analysis as there is possibly a reason why AMPs differ e.g. colistin

# %%
sql = '''WITH s AS (
  SELECT bnf_code, nm, avail_restrict
  FROM dmd.amp
  WHERE avail_restrict != 9 AND bnf_code IS NOT NULL

  UNION DISTINCT

  SELECT vmp.bnf_code, vmp.nm, amp.avail_restrict
  FROM dmd.vmp
  INNER JOIN dmd.amp
    ON vmp.id = amp.vmp
  WHERE amp.avail_restrict != 9 AND vmp.bnf_code IS NOT NULL

  ORDER BY bnf_code
)

SELECT bnf_code, nm,  hospital_only, COUNT(*) AS c
FROM (
  SELECT
    bnf_code,
    nm,
    CASE COUNT(CASE WHEN avail_restrict = 8 THEN 1 ELSE NULL END)
    WHEN 0 THEN "Not hospital only"
    WHEN COUNT(*) THEN "Hospital only"
    ELSE "Mixture"
    END AS hospital_only
  FROM
    s
  WHERE
    avail_restrict != 9 AND
    bnf_code IS NOT NULL    
  GROUP BY
    bnf_code, nm
  ORDER BY
    bnf_code
) WHERE hospital_only = "Mixture"
GROUP BY hospital_only, bnf_code, nm
ORDER BY bnf_code'''

df_mixed = bq.cached_read(sql, csv_path='data/df_mixed.csv', use_cache=True)
pd.set_option('display.max_rows', None) 
df_mixed
# Out:
#             bnf_code                                                 nm  \
# 0    0103050R0AAACAC  Pantoprazole 40mg powder for solution for inje...
# 1    0203020C0AAABAB    Adenosine 30mg/10ml solution for infusion vials
# 2    0203020D0AAADAD  Amiodarone 150mg/3ml solution for injection am...
# 3    0203020D0AAADAD  Amiodarone 150mg/3ml concentrate for solution ...
# 4    0204000I0AAAAAA  Labetalol 100mg/20ml solution for injection am...
# 5    0206010I0AAACAC  Isosorbide dinitrate 10mg/10ml solution for in...
# 6    0207010F0AAAAAA  Dopamine 200mg/5ml solution for infusion ampoules
# 7    0207020R0AAAFAF  Noradrenaline (base) 4mg/4ml solution for infu...
# 8    0207030A0AAABAB  Adrenaline (base) 1mg/10ml (1 in 10,000) dilut...
# 9    0208010ABAAACAC  Fondaparinux sodium 7.5mg/0.6ml solution for i...
# 10   0208010C0AAAAAA  Danaparoid sodium 750units/0.6ml solution for ...
# 11   0211000H0AAAEAE  Aprotinin 500,000 Kallikrein inactivator units...
# 12   0211000J0AAAEAE  High Purity Factor IX 500unit powder and solve...
# 13   0211000J0AAAFAF  High Purity Factor IX 1,000unit powder and sol...
# 14   0211000P0AAAAAA  Tranexamic acid 500mg/5ml solution for injecti...
# 15   0304010G0AAAAAA  Chlorphenamine 10mg/1ml solution for injection...
# 16   0406000S0AAACAC                            Ondansetron 8mg tablets
# 17   0407020ADAAALAL  Oxycodone 10mg/1ml solution for injection ampo...
# 18   0407020ADAAAMAM  Oxycodone 20mg/2ml solution for injection ampo...
# 19   0407020ADAAANAN  Oxycodone 50mg/1ml solution for injection ampo...
# 20   0408010A0AAAJAJ  Levetiracetam 500mg/5ml solution for infusion ...
# 21   0408010A0AAAJAJ  Levetiracetam 500mg/5ml concentrate for soluti...
# 22   0408010F0AAABAB                    Clonazepam 500microgram tablets
# 23   0408010F0AAACAC                             Clonazepam 2mg tablets
# 24   0408020T0AAAAAA  Phenytoin sodium 250mg/5ml solution for inject...
# 25   0409030B0AAADAD  Botulinum toxin type A 50unit powder for solut...
# 26   0409030B0AAAEAE  Botulinum toxin type A 100unit powder for solu...
# 27   0501012G0AAACAC  Flucloxacillin 250mg powder for solution for i...
# 28   0501012G0AAADAD  Flucloxacillin 500mg powder for solution for i...
# 29   0501012G0AAAEAE  Flucloxacillin 1g powder for solution for inje...
# 30   0501013C0AAACAC  Amoxicillin 250mg powder for solution for inje...
# 31   0501013C0AAADAD  Amoxicillin 500mg powder for solution for inje...
# 32   0501013C0AAAEAE  Amoxicillin 1g powder for solution for injecti...
# 33   0501013K0AAAEAE  Co-amoxiclav 500mg/100mg powder for solution f...
# 34   0501013K0AAAFAF  Co-amoxiclav 1000mg/200mg powder for solution ...
# 35   0501014S0AAAAAA  Piperacillin 2g / Tazobactam 250mg powder for ...
# 36   0501014S0AAABAB  Piperacillin 4g / Tazobactam 500mg powder for ...
# 37   0501021D0AAAAAA  Cefotaxime 500mg powder for solution for injec...
# 38   0501021D0AAABAB  Cefotaxime 1g powder for solution for injectio...
# 39   0501021E0AAADAD  Cefoxitin 1g powder for solution for injection...
# 40   0501021E0AAAEAE  Cefoxitin 2g powder for solution for injection...
# 41   0501021G0AAABAB  Ceftriaxone 250mg powder for solution for inje...
# 42   0501021G0AAACAC  Ceftriaxone 1g powder for solution for injecti...
# 43   0501021G0AAADAD  Ceftriaxone 2g powder for solution for injecti...
# 44   0501021H0AAAAAA  Ceftazidime 500mg powder for solution for inje...
# 45   0501021H0AAABAB  Ceftazidime 1g powder for solution for injecti...
# 46   0501021H0AAACAC  Ceftazidime 2g powder for solution for injecti...
# 47   0501021J0AAAAAA        Cefuroxime 250mg powder for injection vials
# 48   0501021J0AAABAB        Cefuroxime 750mg powder for injection vials
# 49   0501021J0AAACAC         Cefuroxime 1.5g powder for injection vials
# 50   0501022A0AAAAAA  Meropenem 500mg powder for solution for inject...
# 51   0501022A0AAABAB  Meropenem 1g powder for solution for injection...
# 52   0501022B0AAAAAA  Ertapenem 1g powder for solution for infusion ...
# 53   0501040H0AAAMAM   Gentamicin 80mg/2ml solution for injection vials
# 54   0501050B0AAACAC  Clarithromycin 500mg powder for solution for i...
# 55   0501050K0AAAAAA  Erythromycin 1g powder for solution for infusi...
# 56   0501060E0AAAAAA  Clindamycin 300mg/2ml solution for injection a...
# 57   0501060E0AAABAB  Clindamycin 600mg/4ml solution for injection a...
# 58   0501070I0AAABAB  Colistimethate 1million unit powder for soluti...
# 59   0501070U0AAACAC  Vancomycin 500mg powder for solution for infus...
# 60   0501070U0AAACAC  Vancomycin 500mg powder for concentrate for so...
# 61   0501070U0AAAFAF  Vancomycin 1g powder for solution for infusion...
# 62   0501070U0AAAFAF  Vancomycin 1g powder for concentrate for solut...
# 63   0501070W0AAACAC                Linezolid 600mg/300ml infusion bags
# 64   0501120L0AAADAD  Ciprofloxacin 200mg/100ml solution for infusio...
# 65   0501120L0AAAYAY  Ciprofloxacin 400mg/200ml solution for infusio...
# 66   0502010A0AAAAAA               Posaconazole 40mg/ml oral suspension
# 67   0503010AAAAAAAA      Emtricitabine 200mg / Tenofovir 245mg tablets
# 68   0503010D0AAADAD                            Efavirenz 600mg tablets
# 69   0503010L0AAAAAA                          Atazanavir 150mg capsules
# 70   0503010L0AAABAB                          Atazanavir 200mg capsules
# 71   0503010L0AAADAD                          Atazanavir 300mg capsules
# 72   0503010Z0AAAAAA          Abacavir 600mg / Lamivudine 300mg tablets
# 73   0503021B0AAAAAA  Aciclovir 250mg powder for solution for infusi...
# 74   0503021B0AAABAB  Aciclovir 500mg powder for solution for infusi...
# 75   0503021C0AAAIAI   Aciclovir 250mg/10ml solution for infusion vials
# 76   0503021C0AAAIAI  Aciclovir 250mg/10ml concentrate for solution ...
# 77   0503021C0AAAJAJ   Aciclovir 500mg/20ml solution for infusion vials
# 78   0503022D0AAAAAA  Ganciclovir 500mg powder for solution for infu...
# 79   0503022D0AAAAAA  Ganciclovir 500mg powder for concentrate for s...
# 80   0603020H0AAALAL  Dexamethasone (base) 3.8mg/1ml solution for in...
# 81   0605020Y0AAAAAA                             Tolvaptan 15mg tablets
# 82   0605020Y0AAABAB                             Tolvaptan 30mg tablets
# 83   0606020V0AAABAB  Zoledronic acid 4mg/5ml solution for infusion ...
# 84   0606020V0AAABAB  Zoledronic acid 4mg/5ml concentrate for soluti...
# 85   0606020V0AAADAD            Zoledronic acid 4mg/100ml infusion bags
# 86   0606020V0AAAEAE  Zoledronic acid 4mg/100ml solution for infusio...
# 87   0606020V0AAAFAF  Zoledronic acid 5mg/100ml solution for infusio...
# 88   0606020W0AAACAC  Ibandronic acid 6mg/6ml solution for infusion ...
# 89   0701010T0AAACAC  Oxytocin 10units/1ml solution for injection am...
# 90   0701020K0AAAAAA                         Mifepristone 200mg tablets
# 91   0703021Q0AAAAAA                    Desogestrel 75microgram tablets
# 92   0704050R0AAABAB                             Tadalafil 20mg tablets
# 93   0801000I0AAAGAG  Calcium folinate 15mg/2ml solution for injecti...
# 94   0801010D0AAAAAA  Carmustine 100mg powder and solvent for soluti...
# 95   0801010H0AAACAC  Cyclophosphamide 500mg powder for solution for...
# 96   0801010H0AAADAD  Cyclophosphamide 1g powder for solution for in...
# 97   0801010S0AAADAD  Melphalan 50mg powder and solvent for solution...
# 98   0801020K0AAACAC  Doxorubicin 10mg/5ml solution for injection vials
# 99   0801020K0AAADAD  Doxorubicin 50mg/25ml solution for injection v...
# 100  0801020K0AAAJAJ  Doxorubicin 200mg/100ml solution for infusion ...
# 101  0801020K0AAAJAJ  Doxorubicin 200mg/100ml concentrate for soluti...
# 102  0801020N0AAADAD   Epirubicin 10mg/5ml solution for injection vials
# 103  0801020N0AAAEAE  Epirubicin 50mg/25ml solution for injection vials
# 104  0801020N0AAAFAF  Epirubicin 200mg/100ml solution for infusion v...
# 105  0801020Q0AAAGAG  Mitomycin 20mg powder for solution for injecti...
# 106  0801020R0AAAAAA  Mitoxantrone 20mg/10ml solution for infusion v...
# 107  0801020R0AAAAAA  Mitoxantrone 20mg/10ml concentrate for solutio...
# 108  0801030D0AAAIAI  Cytarabine 100mg/5ml solution for injection vials
# 109  0801030D0AAAJAJ  Cytarabine 500mg/5ml solution for injection vials
# 110  0801030D0AAAKAK    Cytarabine 1g/10ml solution for injection vials
# 111  0801030D0AAALAL    Cytarabine 2g/20ml solution for injection vials
# 112  0801030D0AAAMAM  Cytarabine 500mg/25ml solution for injection v...
# 113  0801030H0AAAEAE  Fluorouracil 2.5g/100ml solution for infusion ...
# 114  0801030H0AAARAR  Fluorouracil 500mg/10ml solution for injection...
# 115  0801030H0AAATAT  Fluorouracil 2.5g/50ml solution for infusion v...
# 116  0801030H0AAAUAU  Fluorouracil 5g/100ml solution for infusion vials
# 117  0801030P0AAANAN  Methotrexate 50mg/2ml solution for injection v...
# 118  0801030P0AACKCK  Methotrexate 1g/10ml solution for injection vials
# 119  0801030P0AACSCS   Methotrexate 5g/50ml solution for infusion vials
# 120  0801030V0AAAAAA                         Capecitabine 500mg tablets
# 121  0801030W0AAACAC  Fludarabine phosphate 50mg/2ml solution for in...
# 122  0801030W0AAACAC  Fludarabine phosphate 50mg/2ml concentrate for...
# 123  0801030X0AAAAAA  Gemcitabine 1g powder for solution for infusio...
# 124  0801030X0AAABAB  Gemcitabine 200mg powder for solution for infu...
# 125  0801030X0AAADAD  Gemcitabine 2g powder for solution for infusio...
# 126  0801040R0AAAAAA   Vinorelbine 10mg/1ml solution for infusion vials
# 127  0801040R0AAABAB   Vinorelbine 50mg/5ml solution for infusion vials
# 128  0801050ADAAAAAA  Trastuzumab 150mg powder for solution for infu...
# 129  0801050AFAAABAB  Topotecan 4mg powder for solution for infusion...
# 130  0801050ALAAAAAA  Oxaliplatin 50mg/10ml solution for infusion vials
# 131  0801050ALAAAAAA  Oxaliplatin 50mg/10ml concentrate for solution...
# 132  0801050ALAAABAB  Oxaliplatin 100mg/20ml solution for infusion v...
# 133  0801050ALAAABAB  Oxaliplatin 100mg/20ml concentrate for solutio...
# 134  0801050ALAAAEAE  Oxaliplatin 200mg/40ml solution for infusion v...
# 135  0801050ALAAAEAE  Oxaliplatin 200mg/40ml concentrate for solutio...
# 136  0801050AWAAAAAA                            Gefitinib 250mg tablets
# 137  0801050BVAAAAAA                            Lenvatinib 4mg capsules
# 138  0801050BVAAABAB                           Lenvatinib 10mg capsules
# 139  0801050D0AAACAC     Docetaxel 20mg/1ml solution for infusion vials
# 140  0801050D0AAACAC  Docetaxel 20mg/1ml concentrate for solution fo...
# 141  0801050D0AAADAD     Docetaxel 80mg/4ml solution for infusion vials
# 142  0801050D0AAADAD  Docetaxel 80mg/4ml concentrate for solution fo...
# 143  0801050D0AAAIAI    Docetaxel 160mg/8ml solution for infusion vials
# 144  0801050D0AAAIAI  Docetaxel 160mg/8ml concentrate for solution f...
# 145  0801050F0AAADAD   Carboplatin 50mg/5ml solution for infusion vials
# 146  0801050F0AAAEAE  Carboplatin 150mg/15ml solution for infusion v...
# 147  0801050F0AAAEAE  Carboplatin 150mg/15ml concentrate for solutio...
# 148  0801050F0AAAFAF  Carboplatin 450mg/45ml solution for infusion v...
# 149  0801050F0AAAFAF  Carboplatin 450mg/45ml concentrate for solutio...
# 150  0801050F0AAAGAG  Carboplatin 600mg/60ml solution for infusion v...
# 151  0801050F0AAAGAG  Carboplatin 600mg/60ml concentrate for solutio...
# 152  0801050I0AAADAD    Cisplatin 50mg/50ml solution for infusion vials
# 153  0801050I0AAAEAE    Cisplatin 10mg/10ml solution for infusion vials
# 154  0801050I0AAAFAF  Cisplatin 100mg/100ml solution for infusion vials
# 155  0801050Q0AAAAAA   Irinotecan 100mg/5ml solution for infusion vials
# 156  0801050Q0AAAAAA  Irinotecan 100mg/5ml concentrate for solution ...
# 157  0801050Q0AAABAB    Irinotecan 40mg/2ml solution for infusion vials
# 158  0801050Q0AAABAB  Irinotecan 40mg/2ml concentrate for solution f...
# 159  0801050Q0AAACAC  Irinotecan 300mg/15ml solution for infusion vials
# 160  0801050Q0AAACAC  Irinotecan 300mg/15ml concentrate for solution...
# 161  0801050V0AAAAAA    Paclitaxel 30mg/5ml solution for infusion vials
# 162  0801050V0AAAAAA  Paclitaxel 30mg/5ml concentrate for solution f...
# 163  0801050V0AAABAB  Paclitaxel 100mg/16.7ml solution for infusion ...
# 164  0801050V0AAABAB  Paclitaxel 100mg/16.7ml concentrate for soluti...
# 165  0801050V0AAACAC  Paclitaxel 150mg/25ml solution for infusion vials
# 166  0801050V0AAACAC  Paclitaxel 150mg/25ml concentrate for solution...
# 167  0801050V0AAADAD  Paclitaxel 300mg/50ml solution for infusion vials
# 168  0801050V0AAADAD  Paclitaxel 300mg/50ml concentrate for solution...
# 169  0801050Y0AAAAAA                        Temozolomide 100mg capsules
# 170  0801050Y0AAABAB                        Temozolomide 250mg capsules
# 171  0801050Y0AAACAC                          Temozolomide 5mg capsules
# 172  0801050Y0AAADAD                         Temozolomide 20mg capsules
# 173  0801050Y0AAAEAE                        Temozolomide 140mg capsules
# 174  0801050Y0AAAFAF                        Temozolomide 180mg capsules
# 175  0802010M0AAAHAH  Mycophenolate mofetil 500mg powder for solutio...
# 176  0802030F0AAAAAA   Rituximab 500mg/50ml solution for infusion vials
# 177  0802030F0AAABAB   Rituximab 100mg/10ml solution for infusion vials
# 178  0802040M0AAADAD  Interferon beta-1b 300microgram powder and sol...
# 179  0901060P0AAAAAA  Pegfilgrastim 6mg/0.6ml solution for injection...
# 180  0902022I0AAAAAA                     Gelatin 4% infusion 500ml bags
# 181  0905013N0AAABAB  Magnesium sulfate 10% (magnesium 0.4mmol/ml) s...
# 182  1001010Q0AAABAB                       Phenylbutazone 100mg tablets
# 183  1001030D0AAACAC  Etanercept 50mg/1ml solution for injection pre...
# 184  1001030D0AAADAD  Etanercept 25mg/0.5ml solution for injection p...
# 185  1001030D0AAAEAE  Etanercept 50mg/1ml solution for injection pre...
# 186  1405010A0AAACAC  Normal immunoglobulin human 10g/200ml solution...
# 187  1405010A0AAANAN  Normal immunoglobulin human 5g/100ml solution ...
# 188  1405010A0AABPBP  Normal immunoglobulin human 5g/50ml solution f...
# 189  1405010A0AABQBQ  Normal immunoglobulin human 10g/100ml solution...
# 190  1405010A0AABRBR  Normal immunoglobulin human 20g/200ml solution...
# 191  1405010A0AABXBX  Normal immunoglobulin human 2g/20ml solution f...
# 192  1501010F0AAABAB   Ketamine 500mg/10ml solution for injection vials
# 193  1501041T0AAABAB  Midazolam 10mg/5ml solution for injection ampo...
# 194  1501043A0AAADAD  Alfentanil 5mg/1ml solution for injection ampo...
# 195  1501050F0AAAAAA  Atracurium besilate 25mg/2.5ml solution for in...
# 196  1501050F0AAABAB  Atracurium besilate 50mg/5ml solution for inje...
# 197  1501050W0AAACAC  Cisatracurium besilate 20mg/10ml solution for ...
# 198  1501050W0AAADAD  Cisatracurium besilate 150mg/30ml solution for...
# 199  1501050X0AAABAB  Rocuronium bromide 100mg/10ml solution for inj...
# 200  1501050X0AAACAC  Rocuronium bromide 50mg/5ml solution for injec...
# 201  1501070F0AAAAAA  Flumazenil 500micrograms/5ml solution for inje...
# 202  1502010C0AAADAD  Bupivacaine 50mg/10ml (0.5%) solution for inje...
# 203  1502010R0AAAAAA  Ropivacaine 20mg/10ml solution for injection a...
# 204  1502010R0AAABAB  Ropivacaine 75mg/10ml solution for injection a...
# 205  1502010R0AAADAD              Ropivacaine 400mg/200ml infusion bags
# 206  1502010R0AAAEAE  Ropivacaine 100mg/10ml solution for injection ...
#
#     hospital_only  c
# 0         Mixture  1
# 1         Mixture  1
# 2         Mixture  1
# 3         Mixture  1
# 4         Mixture  1
# 5         Mixture  1
# 6         Mixture  1
# 7         Mixture  1
# 8         Mixture  1
# 9         Mixture  1
# 10        Mixture  1
# 11        Mixture  1
# 12        Mixture  1
# 13        Mixture  1
# 14        Mixture  1
# 15        Mixture  1
# 16        Mixture  1
# 17        Mixture  1
# 18        Mixture  1
# 19        Mixture  1
# 20        Mixture  1
# 21        Mixture  1
# 22        Mixture  1
# 23        Mixture  1
# 24        Mixture  1
# 25        Mixture  1
# 26        Mixture  1
# 27        Mixture  1
# 28        Mixture  1
# 29        Mixture  1
# 30        Mixture  1
# 31        Mixture  1
# 32        Mixture  1
# 33        Mixture  1
# 34        Mixture  1
# 35        Mixture  1
# 36        Mixture  1
# 37        Mixture  1
# 38        Mixture  1
# 39        Mixture  1
# 40        Mixture  1
# 41        Mixture  1
# 42        Mixture  1
# 43        Mixture  1
# 44        Mixture  1
# 45        Mixture  1
# 46        Mixture  1
# 47        Mixture  1
# 48        Mixture  1
# 49        Mixture  1
# 50        Mixture  1
# 51        Mixture  1
# 52        Mixture  1
# 53        Mixture  1
# 54        Mixture  1
# 55        Mixture  1
# 56        Mixture  1
# 57        Mixture  1
# 58        Mixture  1
# 59        Mixture  1
# 60        Mixture  1
# 61        Mixture  1
# 62        Mixture  1
# 63        Mixture  1
# 64        Mixture  1
# 65        Mixture  1
# 66        Mixture  1
# 67        Mixture  1
# 68        Mixture  1
# 69        Mixture  1
# 70        Mixture  1
# 71        Mixture  1
# 72        Mixture  1
# 73        Mixture  1
# 74        Mixture  1
# 75        Mixture  1
# 76        Mixture  1
# 77        Mixture  1
# 78        Mixture  1
# 79        Mixture  1
# 80        Mixture  1
# 81        Mixture  1
# 82        Mixture  1
# 83        Mixture  1
# 84        Mixture  1
# 85        Mixture  1
# 86        Mixture  1
# 87        Mixture  1
# 88        Mixture  1
# 89        Mixture  1
# 90        Mixture  1
# 91        Mixture  1
# 92        Mixture  1
# 93        Mixture  1
# 94        Mixture  1
# 95        Mixture  1
# 96        Mixture  1
# 97        Mixture  1
# 98        Mixture  1
# 99        Mixture  1
# 100       Mixture  1
# 101       Mixture  1
# 102       Mixture  1
# 103       Mixture  1
# 104       Mixture  1
# 105       Mixture  1
# 106       Mixture  1
# 107       Mixture  1
# 108       Mixture  1
# 109       Mixture  1
# 110       Mixture  1
# 111       Mixture  1
# 112       Mixture  1
# 113       Mixture  1
# 114       Mixture  1
# 115       Mixture  1
# 116       Mixture  1
# 117       Mixture  1
# 118       Mixture  1
# 119       Mixture  1
# 120       Mixture  1
# 121       Mixture  1
# 122       Mixture  1
# 123       Mixture  1
# 124       Mixture  1
# 125       Mixture  1
# 126       Mixture  1
# 127       Mixture  1
# 128       Mixture  1
# 129       Mixture  1
# 130       Mixture  1
# 131       Mixture  1
# 132       Mixture  1
# 133       Mixture  1
# 134       Mixture  1
# 135       Mixture  1
# 136       Mixture  1
# 137       Mixture  1
# 138       Mixture  1
# 139       Mixture  1
# 140       Mixture  1
# 141       Mixture  1
# 142       Mixture  1
# 143       Mixture  1
# 144       Mixture  1
# 145       Mixture  1
# 146       Mixture  1
# 147       Mixture  1
# 148       Mixture  1
# 149       Mixture  1
# 150       Mixture  1
# 151       Mixture  1
# 152       Mixture  1
# 153       Mixture  1
# 154       Mixture  1
# 155       Mixture  1
# 156       Mixture  1
# 157       Mixture  1
# 158       Mixture  1
# 159       Mixture  1
# 160       Mixture  1
# 161       Mixture  1
# 162       Mixture  1
# 163       Mixture  1
# 164       Mixture  1
# 165       Mixture  1
# 166       Mixture  1
# 167       Mixture  1
# 168       Mixture  1
# 169       Mixture  1
# 170       Mixture  1
# 171       Mixture  1
# 172       Mixture  1
# 173       Mixture  1
# 174       Mixture  1
# 175       Mixture  1
# 176       Mixture  1
# 177       Mixture  1
# 178       Mixture  1
# 179       Mixture  1
# 180       Mixture  1
# 181       Mixture  1
# 182       Mixture  1
# 183       Mixture  1
# 184       Mixture  1
# 185       Mixture  1
# 186       Mixture  1
# 187       Mixture  1
# 188       Mixture  1
# 189       Mixture  1
# 190       Mixture  1
# 191       Mixture  1
# 192       Mixture  1
# 193       Mixture  1
# 194       Mixture  1
# 195       Mixture  1
# 196       Mixture  1
# 197       Mixture  1
# 198       Mixture  1
# 199       Mixture  1
# 200       Mixture  1
# 201       Mixture  1
# 202       Mixture  1
# 203       Mixture  1
# 204       Mixture  1
# 205       Mixture  1
# 206       Mixture  1

# %% [markdown]
# On reviewing this list for the vast majority of products it makes no sense why one AMP would be "hospital only" and why another is not. These are probably inconsistencies as companies and the not NHS controls what is "hospital only". We should send this to BSA to support their review processes.

# %% [markdown]
# To continue our analyis let us manually filter the preparations that are obviously not (based on clinical experience) "hospital only" from df_product

# %%
#'this is the list'
names = ["Clonazepam_Tab 500mcg", "Clonazepam_Tab 2mg", "Desogestrel_Tab 75mcg", "Tadalafil_Tab 20mg", "Clonazepam_Tab 2mg", "Ondansetron HCl_Tab 8mg"]

# %%
## let us drop clonazepam before we proceed
#df_filtered = df_hospital[df_hospital["bnf_name"].str.contains(names) == False].sort_values("bnf_name")
df_filtered = df_hospital[~df_hospital['bnf_name'].isin(names)]
df_filtered.head()
# Out:
#    pct      month                              bnf_name         bnf_code  \
# 0  00C 2010-08-01   Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA
# 6  00C 2010-08-01      Midazolam HCl_Inj 2mg/ml 5ml Amp  1501041T0AAABAB
# 7  00C 2010-08-01  Lido HCl/Adren (Base)_Inj 1% 20ml Vl  1502010J0AAAYAY
# 8  00C 2010-08-01      Xylocaine + Adren_Inj 1% 20ml Vl  1502010J0BBAXAY
# 9  00C 2010-09-01  Tranexamic Acid_Inj 100mg/ml 5ml Amp  0211000P0AAAAAA
#
#    total_items  total_cost
# 0            1       10.01
# 6            3       19.54
# 7            4       45.54
# 8            9       25.50
# 9            2       42.77

# %%
##here we plot trend over time.
df_filtered.groupby("month")['total_cost'].sum().plot(kind='line', title="Total cost of dm+d hospital only medicines prescribing")
plt.ylim(0, )
# Out:
# (0, 564178.468398001)

# %% [markdown]
# In 2016 there was a substanitial drop and now the costs are approximatelt £270k per month.

# %% [markdown]
# ## Infrequently prescribed
# Frequently prescribed items are probably not truly "hospital only" medicines anymore. We are interested in infrequently prescribed medicines that are "hospital only" and possibly a mistake. We highlighted some of this in our [zuclopenthixol blog](https://ebmdatalab.net/zuclopenthixol-acetate-a-new-kind-of-measure-on-openprescribing/) and Callum's [high dose dexamethaone blog](https://ebmdatalab.net/opendemocratisation-of-data-guest-blog-high-dose-dexamethasone/) where things aren't flagged as "hospital only" but probably are. Let us set the threshold of items in a year as similar (but arbitrary) to zuclopenthixol at 75

# %%
infreq = df_filtered.loc[(df_filtered['month'] >= '2018-11-01') & (df_filtered['month'] <= '2019-10-01')] ##restrict to last 12 months

# %%
infreq2 = infreq.groupby(["bnf_name", "bnf_code"]).sum().sort_values('total_items', ascending=True).reset_index() ##group and sort by items
infreq2.to_csv("data/infreq_hosponly.csv") ## export to csv for anyone for further investigation/emailing to interested folks

# %%
## Now lets restict to 75 as per rationale above
inf_hosp_only = infreq2.loc[(infreq2['total_items'] < 75)]
pd.set_option('display.max_rows', None) 
inf_hosp_only
# Out:
#                                     bnf_name         bnf_code  total_items  \
# 0                    Infliximab_Inf 100mg Vl  1001030T0AAAAAA            1
# 1                          Talmanco_Tab 20mg  0704050R0BDAAAB            1
# 2                         Sunitinib_Cap 50mg  0801050AMAAACAC            1
# 3                         Sunitinib_Cap 25mg  0801050AMAAABAB            1
# 4               Prostin_E2 Gel 1mg/2.5ml Pfs  0701010I0BBAFAF            1
# 5                 Cefuroxime Sod_Inj 1.5g Vl  0501021J0AAACAC            1
# 6                      Palbociclib_Cap 125mg  0801050CBAAACAC            1
# 7                        Dabrafenib_Cap 75mg  0802040AIAAABAB            1
# 8          Daptomycin_I/V Inf 350mg Vl (Dry)  0501070Y0AAAAAA            1
# 9                       Nintedanib_Cap 100mg  0801050BTAAAAAA            1
# 10             Nexium I.V._Inj 40mg Vl (Dry)  0103050E0BBACAC            1
# 11                  Enbrel_Inj 25mg Vl + Dil  1001030D0BBAAAA            1
# 12  Netupitant/Palonosteron_Cap 300mg/500mcg  0406000AGAAAAAA            1
# 13        Mycophenolate Mofetil_Inj 500mg Vl  0802010M0AAAHAH            1
# 14                    Misoprostol_Tab 400mcg  0701010X0AAAAAA            1
# 15            Mepolizumab_Inj 100mg Vl (Dry)  0304020Y0AAAAAA            1
# 16          Flumazenil_Inj 100mcg/ml 5ml Amp  1501070F0AAAAAA            1
# 17      Levofloxacin_I/V Inf 5mg/ml 100ml Vl  0501120X0AAACAC            1
# 18         Tigecycline_I/V Inf 50mg Vl (Dry)  0501030Y0AAAAAA            1
# 19           Tocilizumab_Inj 162mg/0.9ml Pfs  1001030W0AAADAD            1
# 20    Ciprofloxacin_I/V Inf 2mg/ml 100ml Bag  0501120L0AABEBE            1
# 21         Labetalol HCl_Inj 5mg/ml 20ml Amp  0204000I0AAAAAA            1
# 22               Abatacept_Inj 125mg/1ml Pfs  1001030V0AAABAB            1
# 23         Aciclovir_I/V Inf 25mg/ml 10ml Vl  0503021C0AAAIAI            1
# 24               Arixtra_Inj 1.5mg/0.3ml Pfs  0208010ABBBAEAE            1
# 25        Ustekinumab_I/V Inf 5mg/ml 26ml Vl  0105030B0AAAAAA            1
# 26  Zoledronic Acid_I/V Inf 40mcg/ml 100mlVl  0606020V0AAAEAE            1
# 27        Anidulafungin_I/V Inf Pdr 100mg Vl  0502040A0AAABAB            1
# 28                            Ofev_Cap 100mg  0801050BTBCAAAA            2
# 29      Lumacaftor/Ivacaftor_Tab 200mg/125mg  0307000T0AAAAAA            2
# 30     Fondaparinux Sod_Inj 5mg/ml 0.3ml Pfs  0208010ABAAAEAE            2
# 31                 Mag Sulf_Inj 10% 10ml Amp  0905013N0AAABAB            2
# 32                      Atazanavir_Cap 300mg  0503010L0AAADAD            2
# 33         Daptomycin_I/V Inf 500mg Vl (Dry)  0501070Y0AAABAB            2
# 34            Zinacef_I/M/I/V 750mg Vl (Dry)  0501021J0BBABAB            2
# 35          Paracet_I/V Inf 10mg/ml 50ml Btl  0407010H0AADTDT            2
# 36        Erythromycin_Lactobi I/V Inf 1g Vl  0501050K0AAAAAA            2
# 37    Danaparoid Sod_Inj 1,250u/ml 0.6ml Amp  0208010C0AAAAAA            3
# 38                       Miglustat_Cap 100mg  0908010ACAAAAAA            3
# 39           Methotrexate_Inj 25mg/ml 2ml Vl  0801030P0AAANAN            3
# 40                      Botox_Inj Pdr 50u Vl  0409030B0BCABAD            3
# 41             Etanercept_Inj 25mg/0.5ml Pfs  1001030D0AAADAD            3
# 42               Etanercept_Inj 50mg/1ml Pfs  1001030D0AAACAC            4
# 43                   Fampridine_Tab 10mg M/R  1002010U0AAABAB            4
# 44                       Tofacitinib_Tab 5mg  1001030ABAAABAB            4
# 45           Co-Amoxiclav_Inj 500mg/100mg Vl  0501013K0AAAEAE            4
# 46    Rapifen Intensive Care_Inj 5mg/1ml Amp  1501043A0BBADAD            4
# 47         Botulinum A Toxin_Inj Pdr 200u Vl  0409030B0AAAGAG            5
# 48       Levobupivac HCl_Inj 5mg/ml 10ml Amp  1502010V0AAABAB            5
# 49                        Tolvaptan_Tab 30mg  0605020Y0AAABAB            7
# 50               Toradol_Inj 30mg/ml 1ml Amp  1501042E0BBAAAA            7
# 51          Posaconazole_Oral Susp 200mg/5ml  0502010A0AAAAAA            7
# 52              Amoxicillin Sod_Inj 250mg Vl  0501013C0AAACAC            7
# 53  Zoledronic Acid_I/V Inf 50mcg/ml 100mlVl  0606020V0AAAFAF            7
# 54         Etanercept_Inj 50mg/ml 1ml Pf Pen  1001030D0AAAEAE            7
# 55                       Efavirenz_Tab 600mg  0503010D0AAADAD            7
# 56           Clarithromycin_I/V Inf 500mg Vl  0501050B0AAACAC            7
# 57              Etanercept_Inj 10mg Vl + Dil  1001030D0AAAFAF            8
# 58                    Capecitabine_Tab 500mg  0801030V0AAAAAA            8
# 59               Adren_Inj 1/10,000 10ml Pfs  0207030A0AAABAB            8
# 60  Piperacillin/Tazobactam_I/VInf2g/0.25gVl  0501014S0AAAAAA            9
# 61              Amikacin_Inj 250mg/ml 2ml Vl  0501040C0AAAAAA            9
# 62                     Botox_Inj Pdr 200u Vl  0409030B0BCACAG           10
# 63         Rituximab_I/V Inf 10mg/ml 10ml Vl  0802030F0AAABAB           11
# 64                  Temocillin Sod_Inj 1g Vl  0501012U0AAABAB           13
# 65                   Isavuconazole_Cap 100mg  0502010E0AAAAAA           14
# 66             Erelzi_Inj 50mg/ml 1ml Pf Pen  1001030D0BDACAE           15
# 67                 Amoxicillin Sod_Inj 1g Vl  0501013C0AAAEAE           15
# 68          Gelaspan_Ecobag I/V Inf 4% 500ml  0902022I0BFAAAA           16
# 69  Zoledronic Acid_I/V Inf 800mcg/ml 5ml Vl  0606020V0AAABAB           16
# 70              Vancomycin HCl_I/V Inf 1g Vl  0501070U0AAAFAF           16
# 71     Clopixol Acuphase_Inj 50mg/ml 1ml Amp  040201010BBAAAA           17
# 72                           Ondemet_Tab 8mg  0406000S0BCADAC           18
# 73       Abacavir/Lamivudine_Tab 600mg/300mg  0503010Z0AAAAAA           18
# 74    Zoledronic Acid_I/V Inf 40mcg/ml 100ml  0606020V0AAADAD           19
# 75                  Fluclox Sod_Inj 500mg Vl  0501012G0AAADAD           19
# 76               Cefotaxime Sod_Inj 500mg Vl  0501021D0AAAAAA           20
# 77                         Botox_Inj 100u Vl  0409030B0BCAAAE           23
# 78        Metoprolol Tart_Inj 1mg/ml 5ml Amp  0204000K0AAAAAA           27
# 79     Levobupivac HCl_Inj 2.5mg/ml 10ml Amp  1502010V0AAAAAA           30
# 80                        Nutricia_preOp Liq  090402000BBQFA0           30
# 81                     Fluclox Sod_Inj 1g Vl  0501012G0AAAEAE           33
# 82              Co-Amoxiclav_Inj 1g/200mg Vl  0501013K0AAAFAF           35
# 83            Chirocaine_Inj 5mg/ml 10ml Amp  1502010V0BBABAB           36
# 84            Esomeprazole_Inj 40mg Vl (Dry)  0103050E0AAACAC           40
# 85                 Meropenem_Inj 1g Vl (Dry)  0501022A0AAABAB           41
# 86   Bupivac HCl/Glucose_Inj 5mg/80mg/ml 4ml  1502010C0AAAKAK           42
# 87          Promixin_Inj 1,000,000u Vl (Dry)  0501070I0BCABAB           42
# 88                  Cefotaxime Sod_Inj 1g Vl  0501021D0AAABAB           43
# 89          Methotrexate_Inj 2.5mg/ml 2ml Vl  0801030P0AAAIAI           43
# 90       Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA           44
# 91            Ceftazidime Pentahyd_Inj 1g Vl  0501021H0AAABAB           48
# 92         Botulinum A Toxin_Inj Pdr 100u Vl  0409030B0AAAEAE           50
# 93                Omeprazole_I/V Inf 40mg Vl  0103050P0AAAVAV           54
# 94               Cefuroxime Sod_Inj 750mg Vl  0501021J0AAABAB           61
# 95   Emtricitabine/Tenofovir_Tab 200mg/245mg  0503010AAAAAAAA           62
# 96               Arixtra_Inj 7.5mg/0.6ml Pfs  0208010ABBBACAC           63
# 97            Ceftazidime Pentahyd_Inj 2g Vl  0501021H0AAACAC           66
# 98      Enbrel_Inj 50mg/ml 1ml Pf MyClic Pen  1001030D0BBAFAE           66
# 99  Piperacillin/Tazobactam_I/VInf 4g/0.5gVl  0501014S0AAABAB           67
#
#       total_cost
# 0      385.99506
# 1      387.55282
# 2      104.18993
# 3     1458.50136
# 4       12.33820
# 5      394.33493
# 6     2740.73011
# 7       46.56671
# 8       57.57535
# 9     1996.62317
# 10     110.50230
# 11     331.94021
# 12      64.07797
# 13       8.16968
# 14     416.32987
# 15     780.64878
# 16      13.56542
# 17      69.62600
# 18     809.99619
# 19     211.99762
# 20     130.01919
# 21    2172.41192
# 22    1124.12878
# 23      27.84464
# 24      23.43598
# 25    1993.36175
# 26     247.88304
# 27    1587.14672
# 28      66.48725
# 29    3718.49476
# 30      87.52638
# 31      68.52131
# 32      18.99706
# 33    1473.62755
# 34      13.06143
# 35      40.89140
# 36     681.50947
# 37    2223.45151
# 38   23482.32750
# 39     615.36197
# 40     250.64126
# 41     581.05275
# 42    1659.12012
# 43    1008.75682
# 44    1933.04257
# 45     119.16762
# 46     107.65314
# 47    2054.67445
# 48       9.17635
# 49    1940.40835
# 50     136.39249
# 51   15333.27620
# 52     114.08749
# 53    1682.84508
# 54    2590.72792
# 55     637.29848
# 56     568.54543
# 57     265.91301
# 58    1595.66630
# 59     272.15010
# 60    1384.52325
# 61    3636.34686
# 62    4105.31290
# 63    2622.79361
# 64    4087.77178
# 65    9701.02969
# 66   20899.42333
# 67     313.61784
# 68    2482.64135
# 69    2478.07403
# 70    1190.05724
# 71     611.34237
# 72    1630.26282
# 73    3413.70939
# 74    2710.82710
# 75    1026.84155
# 76     266.15719
# 77    4687.13717
# 78    2766.65919
# 79     286.28230
# 80    1260.74271
# 81    4074.69740
# 82     889.71951
# 83      67.65898
# 84    4845.72160
# 85   25187.70880
# 86     129.84565
# 87    7398.46579
# 88     470.69244
# 89    1272.67168
# 90     685.96569
# 91    7872.45560
# 92   13696.82572
# 93    6784.42900
# 94    2950.77259
# 95   15568.93342
# 96    9641.85404
# 97    5708.63662
# 98  127340.46087
# 99   15634.70046

# %% [markdown]
# In the last year there are quite a few medicines that I have never heard of, that seem more suitable for secondary care but are being prescribed by practices. This is possible for rare unique cases although we must be mindful for errors abd this requires further investigation. For example is there any circumstance where a GP would prescribe _Rapifen Intensive Care_ which is a powerful opioid? Enbrel cost over £100k in primary care - this should be supplied through secondary care to avail of discounts?

# %% [markdown]
# ## Prototype Measure and Maps

# %%
##get list size info for a measure per 1000 patients
sql2 = """
SELECT month, 
pct_id AS pct,
AVG(total_list_size) AS list_size
FROM ebmdatalab.hscic.practice_statistics
group by 
month, pct
order by
month, pct,
list_size
"""
df_list = bq.cached_read(sql2, csv_path='data/listsize.csv')
df_list['month'] = df_list['month'].astype('datetime64[ns]')
df_list.head(5)
# Out:
#        month  pct    list_size
# 0 2014-11-01  NaN     0.000000
# 1 2014-11-01  00C  7616.000000
# 2 2014-11-01  00D  5662.509804
# 3 2014-11-01  00F  6102.176471
# 4 2014-11-01  00G  8058.750000

# %%
ccg_total_hosp = df_filtered.groupby(["month", "pct"])["total_items","total_cost"].sum().reset_index()
ccg_total_hosp.head()
# Out:
#        month  pct  total_items  total_cost
# 0 2010-08-01  00C           17      100.59
# 1 2010-08-01  00D           71     1235.15
# 2 2010-08-01  00J           66     1311.20
# 3 2010-08-01  00K           62      335.53
# 4 2010-08-01  00L           61     1590.57

# %%
x = df_filtered.groupby(["month", "pct", "bnf_name", "bnf_code"])["total_items","total_cost"].sum().reset_index()
x.head()
# Out:
#        month  pct                              bnf_name         bnf_code  \
# 0 2010-08-01  00C  Lido HCl/Adren (Base)_Inj 1% 20ml Vl  1502010J0AAAYAY
# 1 2010-08-01  00C      Midazolam HCl_Inj 2mg/ml 5ml Amp  1501041T0AAABAB
# 2 2010-08-01  00C      Xylocaine + Adren_Inj 1% 20ml Vl  1502010J0BBAXAY
# 3 2010-08-01  00C   Zuclopenth Acet_Inj 50mg/ml 1ml Amp  040201010AAAAAA
# 4 2010-08-01  00D     Colistimeth Sod_Inj 1,000,000u Vl  0501070I0AAABAB
#
#    total_items  total_cost
# 0            4       45.54
# 1            3       19.54
# 2            9       25.50
# 3            1       10.01
# 4            6      516.22

# %%
#merge dataframes and cost / 10000

hosp_df_1000 = pd.merge(ccg_total_hosp, df_list, on=['month', 'pct'])
hosp_df_1000['cost_per_1000'] = 1000* (hosp_df_1000['total_cost']/hosp_df_1000['list_size'])
hosp_df_1000['items_per_1000'] = 1000* (hosp_df_1000['total_items']/hosp_df_1000['list_size'])
hosp_df_1000.head(5)
# Out:
#        month  pct  total_items  total_cost    list_size  cost_per_1000  \
# 0 2014-11-01  00C           11     3016.90  7616.000000     396.126576
# 1 2014-11-01  00D           92     8384.34  5662.509804    1480.675582
# 2 2014-11-01  00J          124     3495.30  6094.536585     573.513663
# 3 2014-11-01  00K           48      453.93  6354.130435      71.438571
# 4 2014-11-01  00L           74      986.79  6852.085106     144.013097
#
#    items_per_1000
# 0        1.444328
# 1       16.247212
# 2       20.346092
# 3        7.554141
# 4       10.799632

# %%
#create sample deciles & prototype measure
charts.deciles_chart(
        hosp_df_1000,
        period_column='month',
        column='cost_per_1000',
        title="Hosp cost per 1000",
        show_outer_percentiles=False)

#add in example CCG (Islington)
df_subject = hosp_df_1000.loc[hosp_df_1000['pct'] == '08H']
plt.plot(df_subject['month'], df_subject['cost_per_1000'], 'r--')

plt.show()

# %%
#create sample deciles & prototype measure
charts.deciles_chart(
        hosp_df_1000,
        period_column='month',
        column='items_per_1000',
        title="Hosp items per 1000",
        show_outer_percentiles=False)

#add in example CCG (Islington)
df_subject = hosp_df_1000.loc[hosp_df_1000['pct'] == '08H']
plt.plot(df_subject['month'], df_subject['items_per_1000'], 'r--')

plt.show()

# %% [markdown]
# This will require further thought and discussion with users before deploying a measure due to noise of  antibiotics etc. Potentially we could deploy a measure on the noise is excluded?

# %%
#create choropeth map of cost per 1000 patients
plt.figure(figsize=(12, 7))
latest_hosp_df_1000 = hosp_df_1000.loc[(hosp_df_1000['month'] >= '2019-04-01') & (hosp_df_1000['month'] <= '2019-10-01')]
plt = maps.ccg_map(latest_hosp_df_1000, title="Hosp Cost per 1000 patients \n Apr - Oct 2019 ", column='cost_per_1000', separate_london=True)
plt.show()

# %%
# CCGs may like to investigate further so lets produce a file for each of them.
# here we create a dataframe csv files for each CCG to investigate further if they wish - these are now available on GitHub

ccg_investigate = df_filtered.groupby(["month", "pct", "bnf_name", "bnf_code"])["total_items","total_cost"].sum().reset_index()

# %%
#here we create the csv in a folder
    
    
        
for ccg_id, ccg_df in ccg_investigate.groupby('pct'):
     ccg_df.to_csv('ccg-data-for-review\{}.csv'.format(ccg_id), index=False)

# %% [markdown]
# ## Electronic Health Records (EHR)

# %% [markdown]
# Our recent work has show prescribing has an effect on prescribing. Theroretically EHRs could be configured to prevent "hospital only" prescribing. Indeed they may be configured this way already. Here we investigate atterns as per EHR vendor.

# %%
sql = """
SELECT
rx.month,
TRIM(Principal_Supplier) AS supplier,
rx.bnf_name,
rx.bnf_code,
SUM(items) AS total_items,
SUM(actual_cost) AS total_cost
FROM
 hscic.normalised_prescribing_standard AS rx
 JOIN (SELECT DISTINCT bnf_code 
  FROM ebmdatalab.dmd.amp
  WHERE avail_restrict = 8 AND bnf_code != '0408010F0AAABAB' AND ##clonazepam
bnf_code != '0408010F0AAACAC') AS dmd ##clonazepam
ON
  rx.bnf_code = dmd.bnf_code
JOIN
  hscic.ccgs AS ccgs
ON
  rx.pct=ccgs.code
JOIN
  alex.vendors AS software
ON
  software.ODS = rx.practice
  AND date(software.Date) = date(rx.month)
GROUP BY
rx.month,
supplier,
rx.bnf_name,
rx.bnf_code
ORDER BY
month"""



df_ehr_hosp = bq.cached_read(sql, csv_path='data/df_ehr_hosp.csv')
df_ehr_hosp['month'] = df_ehr_hosp['month'].astype('datetime64[ns]')
df_ehr_hosp.head(3)
# Out:
#        month   supplier                                  bnf_name  \
# 0 2016-01-01  Microtest  Midazolam HCl_Inj 2mg/ml 5ml Amp
# 1 2016-01-01        TPP  Botox_Inj 100u Vl
# 2 2016-01-01       INPS  Pantoprazole_Inj 40mg Vl
#
#           bnf_code  total_items  total_cost
# 0  1501041T0AAABAB            2        5.54
# 1  0409030B0BCAAAE            1      255.30
# 2  0103050R0AAACAC            2      528.42

# %%
sql = '''
WITH presentations_with_some_hospital_only_amps AS (
  SELECT bnf_code
  FROM dmd.amp
  WHERE avail_restrict = 8 and avail_restrict !=9 AND bnf_code IS NOT NULL ##8 relates to hospital only in dmd
  
  UNION DISTINCT 
  
  SELECT vmp.bnf_code
  FROM dmd.vmp
  INNER JOIN dmd.amp
    ON vmp.id = amp.vmp
  WHERE amp.avail_restrict = 8 AND vmp.bnf_code IS NOT NULL
)

SELECT
  TRIM(Principal_Supplier) AS supplier,
  month,
  presentation AS bnf_name,
  bnf_code,
  SUM(items) AS total_items,
  SUM(actual_cost) AS total_cost
FROM
  hscic.normalised_prescribing_standard AS rx
INNER JOIN
  hscic.ccgs
ON
  rx.pct = ccgs.code
INNER JOIN
  hscic.bnf
ON
  rx.bnf_code = bnf.presentation_code
INNER JOIN
  alex.vendors AS software
ON
  software.ODS = rx.practice
  AND date(software.Date) = date(rx.month)
WHERE
  org_type = 'CCG'
  AND bnf_code IN (SELECT bnf_code FROM presentations_with_some_hospital_only_amps) 
  AND bnf_code NOT LIKE "0703021Q0AA%" #desogestrel
  AND bnf_code NOT LIKE "0408010F0AA%" #clonazepam 
  AND bnf_code NOT LIKE "0704050R0AA%" #tadalafil
  AND bnf_code NOT LIKE "0406000S0AA%" #ondansetron
GROUP BY
  supplier,
  month,
  bnf_code,
  bnf_name
ORDER BY
  supplier,
  month,
  bnf_code
'''


df_ehr_hosp_only = bq.cached_read(sql, csv_path='data/df_ehr_hosp_only.csv', use_cache=True)
df_ehr_hosp_only['month'] = df_ehr_hosp_only['month'].astype('datetime64[ns]')
df_ehr_hosp_only.head()
# Out:
#   supplier      month                                  bnf_name  \
# 0     EMIS 2016-01-01                Omeprazole_I/V Inf 40mg Vl
# 1     EMIS 2016-01-01                  Pantoprazole_Inj 40mg Vl
# 2     EMIS 2016-01-01  Fondaparinux Sod_Inj 12.5mg/ml 0.6ml Pfs
# 3     EMIS 2016-01-01               Arixtra_Inj 7.5mg/0.6ml Pfs
# 4     EMIS 2016-01-01      Tranexamic Acid_Inj 100mg/ml 5ml Amp
#
#           bnf_code  total_items  total_cost
# 0  0103050P0AAAVAV            2      348.11
# 1  0103050R0AAACAC            1      132.16
# 2  0208010ABAAACAC           35     6728.47
# 3  0208010ABBBACAC            1       10.87
# 4  0211000P0AAAAAA           32     1623.77

# %%
##groupby bnf name  to see "biggest offenders" in terms of items
df_product_ehr = df_ehr_hosp_only.groupby(['bnf_code', 'bnf_name']).sum().sort_values(by = 'total_items', ascending = False)
df_product_ehr
# Out:
#                                                           total_items  \
# bnf_code        bnf_name
# 1502010J0BBAXAY Xylocaine + Adren_Inj 1% 20ml Vl               203780
# 0407020ADAAALAL Oxycodone HCl_Inj 10mg/ml 1ml Amp               88029
# 1502010J0AAAYAY Lido HCl/Adren (Base)_Inj 1% 20ml Vl            75832
# 1502010C0BBAJAD Marcain_Plain Inj 0.5% 10ml Polyamp             19505
# 0501070I0AAABAB Colistimeth Sod_Inj 1,000,000u Vl               15675
# 0407020ADAAAMAM Oxycodone HCl_Inj 10mg/ml 2ml Amp               13783
# 0407020ADAAANAN Oxycodone HCl_Inj 50mg/ml 1ml Amp               11388
# 1501041T0AAABAB Midazolam HCl_Inj 2mg/ml 5ml Amp                 9173
# 1502010C0AAADAD Bupivac HCl_Inj 0.5% 50mg/10ml Amp               6562
# 0304010G0AAAAAA Chlorphenamine Mal_Inj 10mg/ml 1ml Amp           3922
# 1501043A0AAADAD Alfentanil HCl_Inj 5mg/ml 1ml Amp                3800
# 0603020H0AAALAL Dexameth Sod Phos Base_Inj 3.8mg/ml1mlVl         2554
# 0208010ABAAACAC Fondaparinux Sod_Inj 12.5mg/ml 0.6ml Pfs         2532
# 0211000P0AAAAAA Tranexamic Acid_Inj 100mg/ml 5ml Amp             2317
# 0501021G0AAADAD Ceftriaxone Sod_Inj 2g Vl                        2297
# 0501040H0AAAMAM Gentamicin Sulf_Inj 40mg/ml 2ml Vl               2221
# 0501021G0AAACAC Ceftriaxone Sod_Inj 1g Vl                        2060
# 1502010C0BBAHAK Marcain_Heavy Inj 4ml Amp                        1906
# 0704050B0BCAIBN Viridal Duo_S/Pack Inj 40mcg Cart                1632
# 0704050B0BCAGBL Viridal Duo_S/Pack Inj 20mcg Cart                1317
# 0704050B0BCAHBM Viridal Duo_S/Pack Inj 10mcg Cart                1187
# 0408010A0AAAJAJ Levetiracetam_I/V Inf 100mg/ml 5ml Vl            1174
# 0704050B0AABNBN Alprostadil_S/Pack Inj 40mcg Cart                 832
# 1501042E0AAAAAA Ketorolac Trometamol_Inj 30mg/ml 1ml Amp          745
# 0501013C0AAADAD Amoxicillin Sod_Inj 500mg Vl                      732
# 0501022B0AAAAAA Ertapenem Sod_I/V Inf 1g Vl (Dry)                 693
# 0103050R0AAACAC Pantoprazole_Inj 40mg Vl                          679
# 0501021G0AAABAB Ceftriaxone Sod_Inj 250mg Vl                      675
# 1501010F0AAABAB Ketamine_Inj 50mg/ml 10ml Vl                      645
# 0501022A0AAAAAA Meropenem_Inj 500mg Vl (Dry)                      639
# 1001010Q0AAABAB Phenylbutazone_Tab 100mg                          578
# 0704050B0AABLBL Alprostadil_S/Pack Inj 20mcg Cart                 552
# 0605020Y0AAAAAA Tolvaptan_Tab 15mg                                480
# 1502010V0AAAAAA Levobupivac HCl_Inj 2.5mg/ml 10ml Amp             399
# 0704050B0AABMBM Alprostadil_S/Pack Inj 10mcg Cart                 377
# 0208010ABBBACAC Arixtra_Inj 7.5mg/0.6ml Pfs                       323
# 0501022A0AAABAB Meropenem_Inj 1g Vl (Dry)                         315
# 040201010AAAAAA Zuclopenth Acet_Inj 50mg/ml 1ml Amp               276
# 0501021D0AAABAB Cefotaxime Sod_Inj 1g Vl                          238
# 090402000BBQFA0 Nutricia_preOp Liq                                237
# 0501021J0AAABAB Cefuroxime Sod_Inj 750mg Vl                       220
# 0501070U0AAACAC Vancomycin HCl_I/V Inf 500mg Vl                   198
# 0501021H0AAABAB Ceftazidime Pentahyd_Inj 1g Vl                    184
# 0103050E0AAACAC Esomeprazole_Inj 40mg Vl (Dry)                    174
# 0501014S0AAABAB Piperacillin/Tazobactam_I/VInf 4g/0.5gVl          165
# 1502010C0AAAKAK Bupivac HCl/Glucose_Inj 5mg/80mg/ml 4ml           163
# 0501040C0AAAAAA Amikacin_Inj 250mg/ml 2ml Vl                      162
# 1502010V0BBABAB Chirocaine_Inj 5mg/ml 10ml Amp                    161
# 0501013K0AAAFAF Co-Amoxiclav_Inj 1g/200mg Vl                      149
# 0501012G0AAAEAE Fluclox Sod_Inj 1g Vl                             145
# 0801030P0AAANAN Methotrexate_Inj 25mg/ml 2ml Vl                   143
# 0501070U0AAAFAF Vancomycin HCl_I/V Inf 1g Vl                      142
# 0503010AAAAAAAA Emtricitabine/Tenofovir_Tab 200mg/245mg           141
# 1502010V0BBAAAA Chirocaine_Inj 2.5mg/ml 10ml Amp                  132
# 0801030P0AAAIAI Methotrexate_Inj 2.5mg/ml 2ml Vl                  129
# 0501021H0AAACAC Ceftazidime Pentahyd_Inj 2g Vl                    126
# 0501070I0BCABAB Promixin_Inj 1,000,000u Vl (Dry)                  124
# 0409030B0BCAAAE Botox_Inj 100u Vl                                 122
# 0501012G0AAADAD Fluclox Sod_Inj 500mg Vl                           91
# 0409030B0AAAEAE Botulinum A Toxin_Inj Pdr 100u Vl                  89
# 0501013K0AAAEAE Co-Amoxiclav_Inj 500mg/100mg Vl                    86
# 0103050P0AAAVAV Omeprazole_I/V Inf 40mg Vl                         82
# 0503010Z0AAAAAA Abacavir/Lamivudine_Tab 600mg/300mg                80
# 040201010BBAAAA Clopixol Acuphase_Inj 50mg/ml 1ml Amp              80
# 0501012G0AAACAC Fluclox Sod_Inj 250mg Vl                           77
# 0606020V0AAABAB Zoledronic Acid_I/V Inf 800mcg/ml 5ml Vl           74
# 1001030D0AAAEAE Etanercept_Inj 50mg/ml 1ml Pf Pen                  72
# 0204000K0AAAAAA Metoprolol Tart_Inj 1mg/ml 5ml Amp                 70
# 0501021D0AAAAAA Cefotaxime Sod_Inj 500mg Vl                        67
# 0606020V0AAADAD Zoledronic Acid_I/V Inf 40mcg/ml 100ml             64
# 0502010A0AAAAAA Posaconazole_Oral Susp 200mg/5ml                   62
# 0406000S0BCADAC Ondemet_Tab 8mg                                    60
# 0501050B0AAACAC Clarithromycin_I/V Inf 500mg Vl                    56
# 0501013C0AAAEAE Amoxicillin Sod_Inj 1g Vl                          55
# 0502010A0BBAAAA Noxafil_Oral Susp 40mg/ml                          54
# 0409030B0BCACAG Botox_Inj Pdr 200u Vl                              54
# 0207030A0AAABAB Adren_Inj 1/10,000 10ml Pfs                        54
# 1001030D0BBACAC Enbrel_Inj 50mg/ml Pfs                             51
# 1501042E0BBAAAA Toradol_Inj 30mg/ml 1ml Amp                        40
# 0502010E0AAAAAA Isavuconazole_Cap 100mg                            38
# 1502010V0AAABAB Levobupivac HCl_Inj 5mg/ml 10ml Amp                35
# 0501014S0AAAAAA Piperacillin/Tazobactam_I/VInf2g/0.25gVl           33
# 1501043A0BBADAD Rapifen Intensive Care_Inj 5mg/1ml Amp             32
# 1001030D0AAAFAF Etanercept_Inj 10mg Vl + Dil                       31
# 0501050K0AAAAAA Erythromycin_Lactobi I/V Inf 1g Vl                 31
# 0501070Y0AAAAAA Daptomycin_I/V Inf 350mg Vl (Dry)                  30
# 0208010C0AAAAAA Danaparoid Sod_Inj 1,250u/ml 0.6ml Amp             28
# 0501012U0AAABAB Temocillin Sod_Inj 1g Vl                           27
# 0605020Y0AAABAB Tolvaptan_Tab 30mg                                 26
# 0802030F0AAABAB Rituximab_I/V Inf 10mg/ml 10ml Vl                  24
# 0902022I0BFAAAA Gelaspan_Ecobag I/V Inf 4% 500ml                   24
# 0201020G0AAAAAA Enoximone_Inj 5mg/ml 20ml Amp                      21
# 1001030D0AAACAC Etanercept_Inj 50mg/1ml Pfs                        21
# 0501070Y0AAABAB Daptomycin_I/V Inf 500mg Vl (Dry)                  20
# 0801000I0AAAGAG Calc Folinate_Inj 7.5mg/ml 2ml Amp                 19
# 0801000I0AAATAT Calc Folinate_Inj 10mg/ml 10ml Vl                  18
# 0801030V0AAAAAA Capecitabine_Tab 500mg                             17
# 1001030D0AAADAD Etanercept_Inj 25mg/0.5ml Pfs                      16
# 0501021J0AAAAAA Cefuroxime Sod_Inj 250mg Vl                        15
# 0409030B0BCABAD Botox_Inj Pdr 50u Vl                               15
# 0606020V0AAAFAF Zoledronic Acid_I/V Inf 50mcg/ml 100mlVl           14
# 0409030B0AAAGAG Botulinum A Toxin_Inj Pdr 200u Vl                  14
# 1001030D0BBAFAE Enbrel_Inj 50mg/ml 1ml Pf MyClic Pen               14
# 0503010D0AAADAD Efavirenz_Tab 600mg                                12
# 0501013C0AAACAC Amoxicillin Sod_Inj 250mg Vl                       12
# 0701010X0AAAAAA Misoprostol_Tab 400mcg                             12
# 0501021H0AAAHAH Ceftazidime Pentahyd_Inj 3g Vl                     11
# 0208010ABAAAEAE Fondaparinux Sod_Inj 5mg/ml 0.3ml Pfs              10
# 0905013N0AAABAB Mag Sulf_Inj 10% 10ml Amp                           9
# 0501021J0AAACAC Cefuroxime Sod_Inj 1.5g Vl                          9
# 1002010U0AAABAB Fampridine_Tab 10mg M/R                             8
# 0409030B0AAADAD Botulinum A Toxin_Inj Pdr 50u Vl                    8
# 1501070F0AAAAAA Flumazenil_Inj 100mcg/ml 5ml Amp                    8
# 0501021H0AAAAAA Ceftazidime Pentahyd_Inj 500mg Vl                   8
# 0606020V0AAAEAE Zoledronic Acid_I/V Inf 40mcg/ml 100mlVl            7
# 0605010Z0AAAEAE Pegvisomant_Inj 30mg Vl + Dil                       7
# 0103050E0BBACAC Nexium I.V._Inj 40mg Vl (Dry)                       6
# 0801050BTAAAAAA Nintedanib_Cap 100mg                                6
# 0503010L0AAADAD Atazanavir_Cap 300mg                                6
# 0501021J0BBABAB Zinacef_I/M/I/V 750mg Vl (Dry)                      6
# 1001030V0AAABAB Abatacept_Inj 125mg/1ml Pfs                         5
# 1001030D0AAAAAA Etanercept_Inj 25mg Vl + Dil                        5
# 1308010X0BBAAAA Metvix_Crm 16%                                      5
# 1001030T0AAAAAA Infliximab_Inf 100mg Vl                             5
# 0801050BTAAABAB Nintedanib_Cap 150mg                                4
# 0801050BTBCABAB Ofev_Cap 150mg                                      4
# 1001030D0BBAAAA Enbrel_Inj 25mg Vl + Dil                            4
# 1001030ABAAABAB Tofacitinib_Tab 5mg                                 4
# 0204000I0AAAAAA Labetalol HCl_Inj 5mg/ml 20ml Amp                   4
# 1502010R0AAABAB Ropivacaine HCl_Inj 7.5mg/ml 10ml Amp               4
# 0605010Z0AAACAC Pegvisomant_Inj 20mg Vl + Dil                       4
# 0605010Z0BBACAC Somavert_Inj 20mg Vl + Dil                          4
# 0501060E0AAABAB Clindamycin Phos_Inj 150mg/ml 4ml Amp               4
# 0501120X0AAACAC Levofloxacin_I/V Inf 5mg/ml 100ml Vl                4
# 0606020V0AAAGAG Zoledronic Acid_I/V Inf 50mcg/ml 100ml              3
# 0501120L0AABFBF Ciprofloxacin_I/V Inf 2mg/ml 200ml Bag              3
# 0307000T0AAAAAA Lumacaftor/Ivacaftor_Tab 200mg/125mg                3
# 0801030P0AACKCK Methotrexate_Inj 100mg/ml 10ml Vl                   3
# 0204000E0AAADAD Atenolol_Inj 500mcg/ml 10ml Amp                     3
# 0802010M0AAAHAH Mycophenolate Mofetil_Inj 500mg Vl                  3
# 0701010T0AAACAC Oxytocin_Inj 10u/ml 1ml Amp                         3
# 0406000AGBBAAAA Akynzeo_Cap 300mg/0.5mg                             3
# 0503010B0BBADAD Viramune_Tab 100mg M/R                              2
# 1001030D0BBAEAD Enbrel_Inj 25mg/0.5ml Pfs                           2
# 0503010B0AAADAD Nevirapine_Tab 100mg M/R                            2
# 1001030W0AAAAAA Tocilizumab_I/V Inf 80mg/4ml Vl                     2
# 0801000I0AAAMAM Calc Folinate_Inj 10mg/ml 5ml Vl                    2
# 0501120L0AABEBE Ciprofloxacin_I/V Inf 2mg/ml 100ml Bag              2
# 0802040X0AAAAAA B.C.G._Blad Instillation 12.5mg Vl                  2
# 0501120L0AAADAD Ciprofloxacin_I/V Inf 2mg/ml 100ml Btl              2
# 0501070W0AAACAC Linezolid_I/V Inf 2mg/ml 300ml Bag                  2
# 0408020T0AAAAAA Phenytoin_Sod Inj 50mg/ml 5ml Amp                   2
# 0501040H0AAAHAH Gentamicin Sulf_Inj 5mg/ml 1ml Amp                  2
# 0501030Y0AAAAAA Tigecycline_I/V Inf 50mg Vl (Dry)                   2
# 0501023A0AAABAB Aztreonam_Inj 1g Vl                                 2
# 0501021H0BBACAB Fortum_I/M Or I/V Inj 1g Vl (Dry)                   2
# 0205010Y0BBACAC Revatio_Inj 800mcg/ml 12.5ml Vl                     2
# 0304020Y0AAAAAA Mepolizumab_Inj 100mg Vl (Dry)                      2
# 0802040W0BBAAAA Tysabri_I/V Inf 300mg/15ml Vl                       2
# 0801050BJAAACAC Axitinib_Tab 7mg                                    2
# 0801030P0AAAKAK Methotrexate_Inj 25mg/ml 20ml Vl                    2
# 0801050AWAAAAAA Gefitinib_Tab 250mg                                 2
# 0802040AIAAABAB Dabrafenib_Cap 75mg                                 2
# 0901060P0AAAAAA Pegfilgrastim_Inj 10mg/ml 0.6ml Pfs                 1
# 0801050AMAAAAAA Sunitinib_Cap 12.5mg                                1
# 1108020ADBBABAB Lucentis_Inj 10mg/ml 0.23ml Vl                      1
# 1308010X0AAAAAA Methyl-5-Aminolevulinate_Crm 16%                    1
# 1405010A0AAACAC Hum Nor Imglob_I/V Inf 5% 10g/200ml Vl              1
# 0801050AMAAACAC Sunitinib_Cap 50mg                                  1
# 0205010Y0AAACAC Sildenafil_Inj 800mcg/ml 12.5ml Vl                  1
# 0801050AMAAABAB Sunitinib_Cap 25mg                                  1
# 0501070Y0BBAAAA Cubicin_I/V Inf 350mg Vl (Dry)                      1
# 0801030W0BBAAAA Fludara_Tab 10mg                                    1
# 0701010T0BBACAC Syntocinon_Inj 10u/1ml Amp                          1
# 0408020T0BBAAAA Epanutin_Inj 50mg/ml 5ml Amp                        1
# 0406000AGAAAAAA Netupitant/Palonosteron_Cap 300mg/500mcg            1
# 0203020D0AAADAD Amiodarone HCl_Inj 50mg/ml 3ml Amp                  1
# 0203020C0AAAAAA Adenosine_I/V Inf 3mg/ml 2ml Vl                     1
# 0404000E0AAALAL Caffeine Cit_Inj 20mg/ml 1ml Amp                    1
# 0105030B0AAAAAA Ustekinumab_I/V Inf 5mg/ml 26ml Vl                  1
# 0801030H0AAARAR Fluorouracil_Inj 50mg/ml 10ml Vl                    1
# 0801020R0AAAAAA Mitoxantrone_Inj 2mg/ml 10ml Vl                     1
# 0801010H0AAADAD Cyclophosphamide_Inj 1g Vl                          1
# 1108020ADAAABAB Ranibizumab_Inj 10mg/ml 0.23ml Vl                   1
# 0801050CBAAACAC Palbociclib_Cap 125mg                               1
# 1001030W0AAADAD Tocilizumab_Inj 162mg/0.9ml Pfs                     1
# 0701010I0BBAFAF Prostin_E2 Gel 1mg/2.5ml Pfs                        1
# 0606020P0AAAJAJ Pamidronate Disod_I/V Inf 3mg/ml 10ml Vl            1
# 0908010ACAAAAAA Miglustat_Cap 100mg                                 1
# 0908010AHBBAAAA Myozyme_I/V Inf 50mg Vl (Dry)                       1
# 0606020P0AAAIAI Pamidronate Disod_I/V Inf 3mg/ml 5ml Vl             1
# 1001010Q0AAACAC Phenylbutazone_Tab 200mg                            1
# 0606020P0AAAHAH Pamidronate Disod_I/V Inf 9mg/ml 10ml Vl            1
# 0802040W0AAAAAA Natalizumab_I/V Inf 20mg/ml 15ml Vl                 1
# 0605010Z0BBAAAA Somavert_Inj 10mg Vl + Dil                          1
# 0407010H0AADTDT Paracet_I/V Inf 10mg/ml 50ml Btl                    1
# 0704050R0BDAAAB Talmanco_Tab 20mg                                   1
# 0503021B0AAAAAA Aciclovir Sod_Inf I/V 250mg Vl (Dry)                1
# 1001030D0AAAGAG Etanercept_Inj 50mg/ml 0.5ml Pf Pen                 1
# 0503010D0AAACAC Efavirenz_Cap 50mg                                  1
# 0701010T0AAABAB Oxytocin_Inj 5u/ml 1ml Amp                          1
# 0802030F0AAAAAA Rituximab_I/V Inf 10mg/ml 50ml Vl                   1
# 0502040A0AAABAB Anidulafungin_I/V Inf Pdr 100mg Vl                  1
# 1001030T0BBAAAA Remicade_Inf 100mg Vl                               1
# 1001030T0BCAAAA Remsima_Inf 100mg Vl                                1
# 1001030T0BDAAAA Inflectra_Inf 100mg Vl                              1
# 1001030V0AAAAAA Abatacept_I/V Inf 250mg Vl (Dry)                    1
# 0501120X0AAADAD Levofloxacin_I/V Inf 5mg/ml 100ml Bag               1
# 0503021C0AAAIAI Aciclovir_I/V Inf 25mg/ml 10ml Vl                   1
#
#                                                             total_cost
# bnf_code        bnf_name
# 1502010J0BBAXAY Xylocaine + Adren_Inj 1% 20ml Vl          3.950339e+05
# 0407020ADAAALAL Oxycodone HCl_Inj 10mg/ml 1ml Amp         1.571715e+06
# 1502010J0AAAYAY Lido HCl/Adren (Base)_Inj 1% 20ml Vl      1.463573e+05
# 1502010C0BBAJAD Marcain_Plain Inj 0.5% 10ml Polyamp       4.270855e+04
# 0501070I0AAABAB Colistimeth Sod_Inj 1,000,000u Vl         1.603870e+06
# 0407020ADAAAMAM Oxycodone HCl_Inj 10mg/ml 2ml Amp         8.101021e+05
# 0407020ADAAANAN Oxycodone HCl_Inj 50mg/ml 1ml Amp         2.626341e+06
# 1501041T0AAABAB Midazolam HCl_Inj 2mg/ml 5ml Amp          6.058570e+04
# 1502010C0AAADAD Bupivac HCl_Inj 0.5% 50mg/10ml Amp        1.102979e+04
# 0304010G0AAAAAA Chlorphenamine Mal_Inj 10mg/ml 1ml Amp    3.202194e+05
# 1501043A0AAADAD Alfentanil HCl_Inj 5mg/ml 1ml Amp         1.845032e+05
# 0603020H0AAALAL Dexameth Sod Phos Base_Inj 3.8mg/ml1mlVl  5.662002e+04
# 0208010ABAAACAC Fondaparinux Sod_Inj 12.5mg/ml 0.6ml Pfs  5.109903e+05
# 0211000P0AAAAAA Tranexamic Acid_Inj 100mg/ml 5ml Amp      5.489864e+04
# 0501021G0AAADAD Ceftriaxone Sod_Inj 2g Vl                 3.338136e+05
# 0501040H0AAAMAM Gentamicin Sulf_Inj 40mg/ml 2ml Vl        1.442358e+05
# 0501021G0AAACAC Ceftriaxone Sod_Inj 1g Vl                 1.162052e+05
# 1502010C0BBAHAK Marcain_Heavy Inj 4ml Amp                 4.679487e+03
# 0704050B0BCAIBN Viridal Duo_S/Pack Inj 40mcg Cart         9.081025e+04
# 0704050B0BCAGBL Viridal Duo_S/Pack Inj 20mcg Cart         5.478214e+04
# 0704050B0BCAHBM Viridal Duo_S/Pack Inj 10mcg Cart         3.706229e+04
# 0408010A0AAAJAJ Levetiracetam_I/V Inf 100mg/ml 5ml Vl     3.728742e+05
# 0704050B0AABNBN Alprostadil_S/Pack Inj 40mcg Cart         4.573541e+04
# 1501042E0AAAAAA Ketorolac Trometamol_Inj 30mg/ml 1ml Amp  1.262748e+04
# 0501013C0AAADAD Amoxicillin Sod_Inj 500mg Vl              1.560139e+04
# 0501022B0AAAAAA Ertapenem Sod_I/V Inf 1g Vl (Dry)         1.574221e+05
# 0103050R0AAACAC Pantoprazole_Inj 40mg Vl                  7.454418e+04
# 0501021G0AAABAB Ceftriaxone Sod_Inj 250mg Vl              3.169609e+03
# 1501010F0AAABAB Ketamine_Inj 50mg/ml 10ml Vl              4.517786e+04
# 0501022A0AAAAAA Meropenem_Inj 500mg Vl (Dry)              1.729369e+05
# 1001010Q0AAABAB Phenylbutazone_Tab 100mg                  6.702807e+04
# 0704050B0AABLBL Alprostadil_S/Pack Inj 20mcg Cart         2.798562e+04
# 0605020Y0AAAAAA Tolvaptan_Tab 15mg                        3.557102e+05
# 1502010V0AAAAAA Levobupivac HCl_Inj 2.5mg/ml 10ml Amp     3.742926e+03
# 0704050B0AABMBM Alprostadil_S/Pack Inj 10mcg Cart         1.380371e+04
# 0208010ABBBACAC Arixtra_Inj 7.5mg/0.6ml Pfs               4.563404e+04
# 0501022A0AAABAB Meropenem_Inj 1g Vl (Dry)                 1.407355e+05
# 040201010AAAAAA Zuclopenth Acet_Inj 50mg/ml 1ml Amp       5.679573e+03
# 0501021D0AAABAB Cefotaxime Sod_Inj 1g Vl                  4.643425e+03
# 090402000BBQFA0 Nutricia_preOp Liq                        1.063884e+04
# 0501021J0AAABAB Cefuroxime Sod_Inj 750mg Vl               1.017709e+04
# 0501070U0AAACAC Vancomycin HCl_I/V Inf 500mg Vl           2.063990e+04
# 0501021H0AAABAB Ceftazidime Pentahyd_Inj 1g Vl            3.737455e+04
# 0103050E0AAACAC Esomeprazole_Inj 40mg Vl (Dry)            1.634892e+04
# 0501014S0AAABAB Piperacillin/Tazobactam_I/VInf 4g/0.5gVl  4.795488e+04
# 1502010C0AAAKAK Bupivac HCl/Glucose_Inj 5mg/80mg/ml 4ml   5.576166e+02
# 0501040C0AAAAAA Amikacin_Inj 250mg/ml 2ml Vl              6.998880e+04
# 1502010V0BBABAB Chirocaine_Inj 5mg/ml 10ml Amp            2.552586e+02
# 0501013K0AAAFAF Co-Amoxiclav_Inj 1g/200mg Vl              4.094276e+03
# 0501012G0AAAEAE Fluclox Sod_Inj 1g Vl                     1.495709e+04
# 0801030P0AAANAN Methotrexate_Inj 25mg/ml 2ml Vl           4.048679e+03
# 0501070U0AAAFAF Vancomycin HCl_I/V Inf 1g Vl              1.514149e+04
# 0503010AAAAAAAA Emtricitabine/Tenofovir_Tab 200mg/245mg   4.227803e+04
# 1502010V0BBAAAA Chirocaine_Inj 2.5mg/ml 10ml Amp          1.975991e+02
# 0801030P0AAAIAI Methotrexate_Inj 2.5mg/ml 2ml Vl          5.015363e+03
# 0501021H0AAACAC Ceftazidime Pentahyd_Inj 2g Vl            2.639374e+04
# 0501070I0BCABAB Promixin_Inj 1,000,000u Vl (Dry)          2.010566e+04
# 0409030B0BCAAAE Botox_Inj 100u Vl                         2.753420e+04
# 0501012G0AAADAD Fluclox Sod_Inj 500mg Vl                  7.739493e+03
# 0409030B0AAAEAE Botulinum A Toxin_Inj Pdr 100u Vl         2.020585e+04
# 0501013K0AAAEAE Co-Amoxiclav_Inj 500mg/100mg Vl           1.899985e+03
# 0103050P0AAAVAV Omeprazole_I/V Inf 40mg Vl                1.048683e+04
# 0503010Z0AAAAAA Abacavir/Lamivudine_Tab 600mg/300mg       1.759403e+04
# 040201010BBAAAA Clopixol Acuphase_Inj 50mg/ml 1ml Amp     1.963852e+03
# 0501012G0AAACAC Fluclox Sod_Inj 250mg Vl                  5.481085e+03
# 0606020V0AAABAB Zoledronic Acid_I/V Inf 800mcg/ml 5ml Vl  1.078663e+04
# 1001030D0AAAEAE Etanercept_Inj 50mg/ml 1ml Pf Pen         2.974541e+04
# 0204000K0AAAAAA Metoprolol Tart_Inj 1mg/ml 5ml Amp        7.621088e+03
# 0501021D0AAAAAA Cefotaxime Sod_Inj 500mg Vl               9.082910e+02
# 0606020V0AAADAD Zoledronic Acid_I/V Inf 40mcg/ml 100ml    9.315659e+03
# 0502010A0AAAAAA Posaconazole_Oral Susp 200mg/5ml          1.083005e+05
# 0406000S0BCADAC Ondemet_Tab 8mg                           7.476990e+03
# 0501050B0AAACAC Clarithromycin_I/V Inf 500mg Vl           4.892488e+03
# 0501013C0AAAEAE Amoxicillin Sod_Inj 1g Vl                 1.250329e+03
# 0502010A0BBAAAA Noxafil_Oral Susp 40mg/ml                 1.758599e+05
# 0409030B0BCACAG Botox_Inj Pdr 200u Vl                     2.099172e+04
# 0207030A0AAABAB Adren_Inj 1/10,000 10ml Pfs               1.560063e+03
# 1001030D0BBACAC Enbrel_Inj 50mg/ml Pfs                    1.018450e+04
# 1501042E0BBAAAA Toradol_Inj 30mg/ml 1ml Amp               6.890008e+02
# 0502010E0AAAAAA Isavuconazole_Cap 100mg                   3.722363e+04
# 1502010V0AAABAB Levobupivac HCl_Inj 5mg/ml 10ml Amp       6.725805e+01
# 0501014S0AAAAAA Piperacillin/Tazobactam_I/VInf2g/0.25gVl  8.651930e+03
# 1501043A0BBADAD Rapifen Intensive Care_Inj 5mg/1ml Amp    1.295357e+03
# 1001030D0AAAFAF Etanercept_Inj 10mg Vl + Dil              1.626396e+03
# 0501050K0AAAAAA Erythromycin_Lactobi I/V Inf 1g Vl        1.206313e+04
# 0501070Y0AAAAAA Daptomycin_I/V Inf 350mg Vl (Dry)         2.576801e+04
# 0208010C0AAAAAA Danaparoid Sod_Inj 1,250u/ml 0.6ml Amp    2.673457e+04
# 0501012U0AAABAB Temocillin Sod_Inj 1g Vl                  7.979726e+03
# 0605020Y0AAABAB Tolvaptan_Tab 30mg                        7.339573e+03
# 0802030F0AAABAB Rituximab_I/V Inf 10mg/ml 10ml Vl         4.926358e+03
# 0902022I0BFAAAA Gelaspan_Ecobag I/V Inf 4% 500ml          2.994472e+03
# 0201020G0AAAAAA Enoximone_Inj 5mg/ml 20ml Amp             5.667373e+03
# 1001030D0AAACAC Etanercept_Inj 50mg/1ml Pfs               8.929629e+03
# 0501070Y0AAABAB Daptomycin_I/V Inf 500mg Vl (Dry)         1.984675e+04
# 0801000I0AAAGAG Calc Folinate_Inj 7.5mg/ml 2ml Amp        1.404727e+03
# 0801000I0AAATAT Calc Folinate_Inj 10mg/ml 10ml Vl         2.434101e+03
# 0801030V0AAAAAA Capecitabine_Tab 500mg                    3.119825e+03
# 1001030D0AAADAD Etanercept_Inj 25mg/0.5ml Pfs             2.651420e+03
# 0501021J0AAAAAA Cefuroxime Sod_Inj 250mg Vl               1.091444e+03
# 0409030B0BCABAD Botox_Inj Pdr 50u Vl                      1.585326e+03
# 0606020V0AAAFAF Zoledronic Acid_I/V Inf 50mcg/ml 100mlVl  3.378393e+03
# 0409030B0AAAGAG Botulinum A Toxin_Inj Pdr 200u Vl         4.872672e+03
# 1001030D0BBAFAE Enbrel_Inj 50mg/ml 1ml Pf MyClic Pen      1.689282e+04
# 0503010D0AAADAD Efavirenz_Tab 600mg                       2.030194e+03
# 0501013C0AAACAC Amoxicillin Sod_Inj 250mg Vl              1.211913e+02
# 0701010X0AAAAAA Misoprostol_Tab 400mcg                    3.789255e+03
# 0501021H0AAAHAH Ceftazidime Pentahyd_Inj 3g Vl            3.864320e+03
# 0208010ABAAAEAE Fondaparinux Sod_Inj 5mg/ml 0.3ml Pfs     4.542023e+02
# 0905013N0AAABAB Mag Sulf_Inj 10% 10ml Amp                 7.829449e+02
# 0501021J0AAACAC Cefuroxime Sod_Inj 1.5g Vl                5.959869e+02
# 1002010U0AAABAB Fampridine_Tab 10mg M/R                   2.014095e+03
# 0409030B0AAADAD Botulinum A Toxin_Inj Pdr 50u Vl          6.969206e+02
# 1501070F0AAAAAA Flumazenil_Inj 100mcg/ml 5ml Amp          2.982736e+02
# 0501021H0AAAAAA Ceftazidime Pentahyd_Inj 500mg Vl         1.100033e+03
# 0606020V0AAAEAE Zoledronic Acid_I/V Inf 40mcg/ml 100mlVl  1.215682e+03
# 0605010Z0AAAEAE Pegvisomant_Inj 30mg Vl + Dil             2.334123e+04
# 0103050E0BBACAC Nexium I.V._Inj 40mg Vl (Dry)             6.181083e+02
# 0801050BTAAAAAA Nintedanib_Cap 100mg                      5.033446e+03
# 0503010L0AAADAD Atazanavir_Cap 300mg                      6.185698e+02
# 0501021J0BBABAB Zinacef_I/M/I/V 750mg Vl (Dry)            5.650919e+01
# 1001030V0AAABAB Abatacept_Inj 125mg/1ml Pfs               3.964993e+03
# 1001030D0AAAAAA Etanercept_Inj 25mg Vl + Dil              1.570490e+03
# 1308010X0BBAAAA Metvix_Crm 16%                            7.947888e+02
# 1001030T0AAAAAA Infliximab_Inf 100mg Vl                   1.905335e+03
# 0801050BTAAABAB Nintedanib_Cap 150mg                      2.392361e+03
# 0801050BTBCABAB Ofev_Cap 150mg                            9.831130e+03
# 1001030D0BBAAAA Enbrel_Inj 25mg Vl + Dil                  1.077070e+03
# 1001030ABAAABAB Tofacitinib_Tab 5mg                       1.933043e+03
# 0204000I0AAAAAA Labetalol HCl_Inj 5mg/ml 20ml Amp         4.038347e+03
# 1502010R0AAABAB Ropivacaine HCl_Inj 7.5mg/ml 10ml Amp     1.178000e+01
# 0605010Z0AAACAC Pegvisomant_Inj 20mg Vl + Dil             2.666687e+04
# 0605010Z0BBACAC Somavert_Inj 20mg Vl + Dil                1.111692e+04
# 0501060E0AAABAB Clindamycin Phos_Inj 150mg/ml 4ml Amp     4.381181e+02
# 0501120X0AAACAC Levofloxacin_I/V Inf 5mg/ml 100ml Vl      1.303639e+03
# 0606020V0AAAGAG Zoledronic Acid_I/V Inf 50mcg/ml 100ml    6.051679e+02
# 0501120L0AABFBF Ciprofloxacin_I/V Inf 2mg/ml 200ml Bag    6.490584e+02
# 0307000T0AAAAAA Lumacaftor/Ivacaftor_Tab 200mg/125mg      1.113764e+04
# 0801030P0AACKCK Methotrexate_Inj 100mg/ml 10ml Vl         4.724987e+02
# 0204000E0AAADAD Atenolol_Inj 500mcg/ml 10ml Amp           3.703462e+02
# 0802010M0AAAHAH Mycophenolate Mofetil_Inj 500mg Vl        5.234597e+02
# 0701010T0AAACAC Oxytocin_Inj 10u/ml 1ml Amp               2.892358e+01
# 0406000AGBBAAAA Akynzeo_Cap 300mg/0.5mg                   7.670099e+02
# 0503010B0BBADAD Viramune_Tab 100mg M/R                    2.123842e+01
# 1001030D0BBAEAD Enbrel_Inj 25mg/0.5ml Pfs                 4.140800e+02
# 0503010B0AAADAD Nevirapine_Tab 100mg M/R                  8.022124e+01
# 1001030W0AAAAAA Tocilizumab_I/V Inf 80mg/4ml Vl           1.899940e+02
# 0801000I0AAAMAM Calc Folinate_Inj 10mg/ml 5ml Vl          1.482714e+02
# 0501120L0AABEBE Ciprofloxacin_I/V Inf 2mg/ml 100ml Bag    5.994692e+02
# 0802040X0AAAAAA B.C.G._Blad Instillation 12.5mg Vl        1.326500e+02
# 0501120L0AAADAD Ciprofloxacin_I/V Inf 2mg/ml 100ml Btl    9.035786e+02
# 0501070W0AAACAC Linezolid_I/V Inf 2mg/ml 300ml Bag        4.615300e+03
# 0408020T0AAAAAA Phenytoin_Sod Inj 50mg/ml 5ml Amp         3.636000e+01
# 0501040H0AAAHAH Gentamicin Sulf_Inj 5mg/ml 1ml Amp        5.522248e+01
# 0501030Y0AAAAAA Tigecycline_I/V Inf 50mg Vl (Dry)         5.989603e+02
# 0501023A0AAABAB Aztreonam_Inj 1g Vl                       7.840708e+01
# 0501021H0BBACAB Fortum_I/M Or I/V Inj 1g Vl (Dry)         3.824820e+02
# 0205010Y0BBACAC Revatio_Inj 800mcg/ml 12.5ml Vl           8.384819e+01
# 0304020Y0AAAAAA Mepolizumab_Inj 100mg Vl (Dry)            1.560354e+03
# 0802040W0BBAAAA Tysabri_I/V Inf 300mg/15ml Vl             2.091619e+03
# 0801050BJAAACAC Axitinib_Tab 7mg                          1.629872e+02
# 0801030P0AAAKAK Methotrexate_Inj 25mg/ml 20ml Vl          2.840785e+02
# 0801050AWAAAAAA Gefitinib_Tab 250mg                       3.879180e+03
# 0802040AIAAABAB Dabrafenib_Cap 75mg                       2.644923e+03
# 0901060P0AAAAAA Pegfilgrastim_Inj 10mg/ml 0.6ml Pfs       6.354321e+02
# 0801050AMAAAAAA Sunitinib_Cap 12.5mg                      2.180569e+03
# 1108020ADBBABAB Lucentis_Inj 10mg/ml 0.23ml Vl            6.867400e+02
# 1308010X0AAAAAA Methyl-5-Aminolevulinate_Crm 16%          1.620500e+02
# 1405010A0AAACAC Hum Nor Imglob_I/V Inf 5% 10g/200ml Vl    3.544577e+02
# 0801050AMAAACAC Sunitinib_Cap 50mg                        1.041899e+02
# 0205010Y0AAACAC Sildenafil_Inj 800mcg/ml 12.5ml Vl        3.364464e+02
# 0801050AMAAABAB Sunitinib_Cap 25mg                        1.458501e+03
# 0501070Y0BBAAAA Cubicin_I/V Inf 350mg Vl (Dry)            8.031598e+02
# 0801030W0BBAAAA Fludara_Tab 10mg                          1.311399e+02
# 0701010T0BBACAC Syntocinon_Inj 10u/1ml Amp                9.600000e-01
# 0408020T0BBAAAA Epanutin_Inj 50mg/ml 5ml Amp              2.271000e+01
# 0406000AGAAAAAA Netupitant/Palonosteron_Cap 300mg/500mcg  2.557500e+02
# 0203020D0AAADAD Amiodarone HCl_Inj 50mg/ml 3ml Amp        8.922710e+00
# 0203020C0AAAAAA Adenosine_I/V Inf 3mg/ml 2ml Vl           5.548000e+01
# 0404000E0AAALAL Caffeine Cit_Inj 20mg/ml 1ml Amp          4.793034e+02
# 0105030B0AAAAAA Ustekinumab_I/V Inf 5mg/ml 26ml Vl        1.993362e+03
# 0801030H0AAARAR Fluorouracil_Inj 50mg/ml 10ml Vl          1.185000e+01
# 0801020R0AAAAAA Mitoxantrone_Inj 2mg/ml 10ml Vl           1.127800e+02
# 0801010H0AAADAD Cyclophosphamide_Inj 1g Vl                1.580000e+01
# 1108020ADAAABAB Ranibizumab_Inj 10mg/ml 0.23ml Vl         5.103300e+02
# 0801050CBAAACAC Palbociclib_Cap 125mg                     2.740730e+03
# 1001030W0AAADAD Tocilizumab_Inj 162mg/0.9ml Pfs           2.119976e+02
# 0701010I0BBAFAF Prostin_E2 Gel 1mg/2.5ml Pfs              1.233820e+01
# 0606020P0AAAJAJ Pamidronate Disod_I/V Inf 3mg/ml 10ml Vl  1.104089e+02
# 0908010ACAAAAAA Miglustat_Cap 100mg                       7.827151e+03
# 0908010AHBBAAAA Myozyme_I/V Inf 50mg Vl (Dry)             1.319317e+03
# 0606020P0AAAIAI Pamidronate Disod_I/V Inf 3mg/ml 5ml Vl   2.552749e+01
# 1001010Q0AAACAC Phenylbutazone_Tab 200mg                  5.311686e+01
# 0606020P0AAAHAH Pamidronate Disod_I/V Inf 9mg/ml 10ml Vl  1.574400e+02
# 0802040W0AAAAAA Natalizumab_I/V Inf 20mg/ml 15ml Vl       1.046910e+03
# 0605010Z0BBAAAA Somavert_Inj 10mg Vl + Dil                2.318091e+02
# 0407010H0AADTDT Paracet_I/V Inf 10mg/ml 50ml Btl          2.045230e+01
# 0704050R0BDAAAB Talmanco_Tab 20mg                         3.875528e+02
# 0503021B0AAAAAA Aciclovir Sod_Inf I/V 250mg Vl (Dry)      1.547251e+01
# 1001030D0AAAGAG Etanercept_Inj 50mg/ml 0.5ml Pf Pen       3.311576e+02
# 0503010D0AAACAC Efavirenz_Cap 50mg                        6.310500e-01
# 0701010T0AAABAB Oxytocin_Inj 5u/ml 1ml Amp                8.334000e+01
# 0802030F0AAAAAA Rituximab_I/V Inf 10mg/ml 50ml Vl         8.081100e+02
# 0502040A0AAABAB Anidulafungin_I/V Inf Pdr 100mg Vl        1.587147e+03
# 1001030T0BBAAAA Remicade_Inf 100mg Vl                     3.890774e+02
# 1001030T0BCAAAA Remsima_Inf 100mg Vl                      3.500852e+02
# 1001030T0BDAAAA Inflectra_Inf 100mg Vl                    3.494555e+02
# 1001030V0AAAAAA Abatacept_I/V Inf 250mg Vl (Dry)          2.797969e+02
# 0501120X0AAADAD Levofloxacin_I/V Inf 5mg/ml 100ml Bag     1.871294e+01
# 0503021C0AAAIAI Aciclovir_I/V Inf 25mg/ml 10ml Vl         2.784464e+01

# %%
df_ehr_hosp_only.groupby(['month', 'supplier']).sum()['total_items'].unstack().plot.line()
plt.legend(loc=(1.04,0))
plt.title("total hosp only items per EHR vendor")
# Out:
# Text(0.5, 1.0, 'total hosp only items per EHR vendor')

# %% [markdown]
# There is no striking trend and we only have EHR data since 2016. We should speak to EHR vendors, nerds and NHS Digital about this. We should have a look at user interface to support further work around EHR/dm+d.
